# %%
# import packages
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '2'

# %%
import tensorflow as tf
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import time
from tensorflow.keras.utils import plot_model
import numpy as np


if not os.path.exists('output'):
    os.makedirs('output')

# %%
# 获取默认的 GPU 设备
default_gpu = tf.test.gpu_device_name()
print(default_gpu)

print(tf.config.list_physical_devices('GPU'))
# Out:
# /device:GPU:0
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 2024-11-14 23:43:34.360085: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-14 23:43:34.929004: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /device:GPU:0 with 22991 MB memory:  -> device: 0, name: NVIDIA TITAN RTX, pci bus id: 0000:86:00.0, compute capability: 7.5

# %%
print("~~~~~~~~~~~MENU~~~~~~~~~~~~~")
print("1: COLORS")
print("2: COLORS_SHAPE")
print("3: 12-CHANNELS")
print("4: CIFAR-10")
print("Note: Run create_noisy_colors.py if first time running software")
datamenu1 = 4

datamenu2 = 0.001

datamenu3 = 6
    
print("Select models to run sequentially (y/n): ")

model1 = input('CO-QCNN (U1): ')

model6 = input('CO-QCNN (U2): ')

print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
# choose dataset to train on

if datamenu1 == 1: 
    datatype = "COLORS"
if datamenu1 == 2: 
    datatype = "COLORS_SHAPE"
if datamenu1 == 3: 
    datatype = "CHANNELS"
if datamenu1 == 4: 
    datatype = "CIFAR10"
    

# choose hyperparameters
num_of_epochs = 50
global_learning_rate = datamenu2
global_batch_size = 128

#classes of CIFAR-10 dataset
classes = datamenu3

# choose image size
resize_x = 10 
resize_y = 10 

# import project functions
# Out:
# ~~~~~~~~~~~MENU~~~~~~~~~~~~~
# 1: COLORS
# 2: COLORS_SHAPE
# 3: 12-CHANNELS
# 4: CIFAR-10
# Note: Run create_noisy_colors.py if first time running software
# Select models to run sequentially (y/n):
# CO-QCNN (U1):  n
# CO-QCNN (U2):  y
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %%
from prepare_data import datasize, build_model_datasets
import generate_output
import models

# list containing train size, image size x, image size y, learning_rate, batch size, test size, dataset, number of epochs
details = [datasize(datatype,classes)[0],resize_x,resize_y,global_learning_rate,global_batch_size,datasize(datatype,classes)[1],datatype,num_of_epochs]

# set model to True to run
############################
if model1 == "y":
    CO_U1_QCNN = True 
else:
    CO_U1_QCNN = False 


if model6 == "y":
    CO_U2_QCNN = True 
else:
    CO_U2_QCNN = False 
    

        

#############################
models_to_train = []
#############################
if CO_U1_QCNN:
    models_to_train.append(models.CO_U1_QCNN_model(datatype,classes))
    

if CO_U2_QCNN:
    models_to_train.append(models.CO_U2_QCNN_model(datatype,classes))

     
#############################

def train_model(model_to_train,classes):
    model = model_to_train
##########################
# print the architecture of the model
    model.summary()
############################
# grab the time the training starts, output folder will be named with this time
    timestr_ = time.strftime("%Y%m%d-%H%M%S")
# compile model
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=global_learning_rate), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# preprocess the chosen dataset
    model_data = build_model_datasets(datatype,details,classes)
# begin to train the model
    model_history = model.fit(model_data[0], model_data[2], validation_data=(model_data[1],model_data[3]) , epochs=num_of_epochs, batch_size=global_batch_size)
# create timestampped folder to save output
    os.mkdir('output/'+timestr_)
# create confusion matrix
    print("CONFUSION MATRIX")
    classes = model_data[4]
    y_pred = model.predict(model_data[1])
    y_pred = np.argmax(y_pred, axis=-1)
    y_pred = y_pred.flatten()
    if datatype == "CHANNELS" or datatype == "CIFAR10":
        y_true = model_data[3].flatten()
    else:
        y_true = model_data[3].numpy().flatten()
    confusion_mtx = confusion_matrix(y_true, y_pred, normalize='true')
    plt.figure(figsize=(16, 16))
    plt.figure()
    plt.imshow(confusion_mtx, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title('Confusion matrix')
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    timestr = time.strftime("%Y%m%d-%H%M%S")
    plt.savefig('output/'+timestr_+'/'+timestr+'_confusion_matrix.png', bbox_inches='tight')

# create learning curves plot
    print("GENERATE LEARNING CURVES")
    generate_output.save_output_imgs(model,model_history,details,timestr_)
# Out:
# 2024-11-14 23:44:03.459527: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22991 MB memory:  -> device: 0, name: NVIDIA TITAN RTX, pci bus id: 0000:86:00.0, compute capability: 7.5
# Circuit Depth: 18

# %%
# train all chosen models   
for x in models_to_train:
    train_model(x,classes)
# Out:
# Model: "CO_U2_QCNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 10, 10, 3)]       0
#
#  CO_U2_QCNN (U2_circuit)     (None, 9, 9, 5)           105
#
#  max_pooling2d (MaxPooling2D  (None, 4, 4, 5)          0
#  )
#
#  flatten (Flatten)           (None, 80)                0
#
#  dense (Dense)               (None, 32)                2592
#
#  dense_1 (Dense)             (None, 6)                 198
#
# =================================================================
# Total params: 2,895
# Trainable params: 2,895
# Non-trainable params: 0
# _________________________________________________________________
# Preparing classes:
# ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog']
# Training Images Per Class: 640
# Testing Images Per Class: 100
# Filtering Training Images: 100%|█████████| 30000/30000 [00:56<00:00, 531.76it/s]
# 3840
# Filtering Testing Images: 100%|███████████| 6000/6000 [00:01<00:00, 3008.51it/s]
# 600
# Train Shape: (3840, 32, 32, 3)
# Test Shape: (600, 32, 32, 3)
# Epoch 1/50
# 2024-11-14 23:45:23.746770: I tensorflow/stream_executor/cuda/cuda_dnn.cc:366] Loaded cuDNN version 8902
# 30/30 [==============================] - 182s 6s/step - loss: 1.7932 - accuracy: 0.1802 - val_loss: 1.7887 - val_accuracy: 0.2033
# Epoch 2/50
# 30/30 [==============================] - 165s 6s/step - loss: 1.7853 - accuracy: 0.1948 - val_loss: 1.7831 - val_accuracy: 0.2317
# Epoch 3/50
# 30/30 [==============================] - 158s 5s/step - loss: 1.7764 - accuracy: 0.2440 - val_loss: 1.7703 - val_accuracy: 0.2517
# Epoch 4/50
# 30/30 [==============================] - 166s 6s/step - loss: 1.7589 - accuracy: 0.2576 - val_loss: 1.7505 - val_accuracy: 0.2683
# Epoch 5/50
# 30/30 [==============================] - 152s 5s/step - loss: 1.7327 - accuracy: 0.3070 - val_loss: 1.7241 - val_accuracy: 0.2783
# Epoch 6/50
# 30/30 [==============================] - 154s 5s/step - loss: 1.7012 - accuracy: 0.3164 - val_loss: 1.7001 - val_accuracy: 0.2783
# Epoch 7/50
# 30/30 [==============================] - 155s 5s/step - loss: 1.6717 - accuracy: 0.3253 - val_loss: 1.6725 - val_accuracy: 0.3033
# Epoch 8/50
# 30/30 [==============================] - 158s 5s/step - loss: 1.6470 - accuracy: 0.3469 - val_loss: 1.6599 - val_accuracy: 0.2900
# Epoch 9/50
# 30/30 [==============================] - 156s 5s/step - loss: 1.6253 - accuracy: 0.3466 - val_loss: 1.6409 - val_accuracy: 0.3083
# Epoch 10/50
# 30/30 [==============================] - 160s 5s/step - loss: 1.6075 - accuracy: 0.3659 - val_loss: 1.6289 - val_accuracy: 0.3317
# Epoch 11/50
# 30/30 [==============================] - 154s 5s/step - loss: 1.5918 - accuracy: 0.3729 - val_loss: 1.6172 - val_accuracy: 0.3500
# Epoch 12/50
# 30/30 [==============================] - 162s 5s/step - loss: 1.5730 - accuracy: 0.3784 - val_loss: 1.5983 - val_accuracy: 0.3450
# Epoch 13/50
# 30/30 [==============================] - 159s 5s/step - loss: 1.5589 - accuracy: 0.3870 - val_loss: 1.5963 - val_accuracy: 0.3450
# Epoch 14/50
# 30/30 [==============================] - 171s 6s/step - loss: 1.5440 - accuracy: 0.3997 - val_loss: 1.5784 - val_accuracy: 0.3533
# Epoch 15/50
# 30/30 [==============================] - 159s 5s/step - loss: 1.5313 - accuracy: 0.4026 - val_loss: 1.5677 - val_accuracy: 0.3583
# Epoch 16/50
# 30/30 [==============================] - 157s 5s/step - loss: 1.5196 - accuracy: 0.4044 - val_loss: 1.5596 - val_accuracy: 0.3550
# Epoch 17/50
# 30/30 [==============================] - 150s 5s/step - loss: 1.5072 - accuracy: 0.4164 - val_loss: 1.5643 - val_accuracy: 0.3483
# Epoch 18/50
# 30/30 [==============================] - 160s 5s/step - loss: 1.4994 - accuracy: 0.4169 - val_loss: 1.5463 - val_accuracy: 0.3633
# Epoch 19/50
# 30/30 [==============================] - 154s 5s/step - loss: 1.4873 - accuracy: 0.4187 - val_loss: 1.5427 - val_accuracy: 0.3633
# Epoch 20/50
# 30/30 [==============================] - 162s 5s/step - loss: 1.4783 - accuracy: 0.4195 - val_loss: 1.5301 - val_accuracy: 0.3783
# Epoch 21/50
# 30/30 [==============================] - 164s 5s/step - loss: 1.4711 - accuracy: 0.4247 - val_loss: 1.5240 - val_accuracy: 0.3700
# Epoch 22/50
# 30/30 [==============================] - 156s 5s/step - loss: 1.4628 - accuracy: 0.4289 - val_loss: 1.5297 - val_accuracy: 0.3717
# Epoch 23/50
# 30/30 [==============================] - 167s 6s/step - loss: 1.4550 - accuracy: 0.4294 - val_loss: 1.5163 - val_accuracy: 0.3750
# Epoch 24/50
# 30/30 [==============================] - 153s 5s/step - loss: 1.4478 - accuracy: 0.4318 - val_loss: 1.5096 - val_accuracy: 0.3783
# Epoch 25/50
# 30/30 [==============================] - 161s 5s/step - loss: 1.4409 - accuracy: 0.4315 - val_loss: 1.5011 - val_accuracy: 0.3800
# Epoch 26/50
# 30/30 [==============================] - 170s 6s/step - loss: 1.4334 - accuracy: 0.4354 - val_loss: 1.4970 - val_accuracy: 0.3783
# Epoch 27/50
# 30/30 [==============================] - 173s 6s/step - loss: 1.4271 - accuracy: 0.4398 - val_loss: 1.4920 - val_accuracy: 0.3900
# Epoch 28/50
# 30/30 [==============================] - 169s 6s/step - loss: 1.4222 - accuracy: 0.4469 - val_loss: 1.4942 - val_accuracy: 0.3817
# Epoch 29/50
# 30/30 [==============================] - 161s 5s/step - loss: 1.4251 - accuracy: 0.4367 - val_loss: 1.4854 - val_accuracy: 0.3900
# Epoch 30/50
# 30/30 [==============================] - 170s 6s/step - loss: 1.4108 - accuracy: 0.4401 - val_loss: 1.4799 - val_accuracy: 0.3950
# Epoch 31/50
# 30/30 [==============================] - 155s 5s/step - loss: 1.4060 - accuracy: 0.4482 - val_loss: 1.4840 - val_accuracy: 0.3817
# Epoch 32/50
# 30/30 [==============================] - 160s 5s/step - loss: 1.4033 - accuracy: 0.4448 - val_loss: 1.4774 - val_accuracy: 0.3900
# Epoch 33/50
# 30/30 [==============================] - 158s 5s/step - loss: 1.4011 - accuracy: 0.4508 - val_loss: 1.4731 - val_accuracy: 0.3883
# Epoch 34/50
# 30/30 [==============================] - 155s 5s/step - loss: 1.3907 - accuracy: 0.4549 - val_loss: 1.4752 - val_accuracy: 0.3933
# Epoch 35/50
# 30/30 [==============================] - 163s 5s/step - loss: 1.3884 - accuracy: 0.4570 - val_loss: 1.4638 - val_accuracy: 0.3983
# Epoch 36/50
# 30/30 [==============================] - 169s 6s/step - loss: 1.3811 - accuracy: 0.4573 - val_loss: 1.4629 - val_accuracy: 0.4117
# Epoch 37/50
# 30/30 [==============================] - 185s 6s/step - loss: 1.3772 - accuracy: 0.4573 - val_loss: 1.4570 - val_accuracy: 0.4000
# Epoch 38/50
# 30/30 [==============================] - 158s 5s/step - loss: 1.3729 - accuracy: 0.4617 - val_loss: 1.4556 - val_accuracy: 0.3967
# Epoch 39/50
# 30/30 [==============================] - 168s 6s/step - loss: 1.3696 - accuracy: 0.4583 - val_loss: 1.4740 - val_accuracy: 0.3967
# Epoch 40/50
# 30/30 [==============================] - 164s 6s/step - loss: 1.3682 - accuracy: 0.4659 - val_loss: 1.4561 - val_accuracy: 0.3967
# Epoch 41/50
# 30/30 [==============================] - 186s 6s/step - loss: 1.3619 - accuracy: 0.4643 - val_loss: 1.4555 - val_accuracy: 0.3967
# Epoch 42/50
# 30/30 [==============================] - 166s 6s/step - loss: 1.3594 - accuracy: 0.4643 - val_loss: 1.4551 - val_accuracy: 0.4117
# Epoch 43/50
# 30/30 [==============================] - 153s 5s/step - loss: 1.3595 - accuracy: 0.4620 - val_loss: 1.4452 - val_accuracy: 0.4017
# Epoch 44/50
# 30/30 [==============================] - 165s 6s/step - loss: 1.3538 - accuracy: 0.4719 - val_loss: 1.4423 - val_accuracy: 0.4100
# Epoch 45/50
# 30/30 [==============================] - 136s 5s/step - loss: 1.3515 - accuracy: 0.4732 - val_loss: 1.4463 - val_accuracy: 0.4000
# Epoch 46/50
# 30/30 [==============================] - 158s 5s/step - loss: 1.3473 - accuracy: 0.4719 - val_loss: 1.4363 - val_accuracy: 0.4100
# Epoch 47/50
# 30/30 [==============================] - 158s 5s/step - loss: 1.3449 - accuracy: 0.4740 - val_loss: 1.4425 - val_accuracy: 0.3950
# Epoch 48/50
# 30/30 [==============================] - 145s 5s/step - loss: 1.3405 - accuracy: 0.4729 - val_loss: 1.4425 - val_accuracy: 0.4083
# Epoch 49/50
# 30/30 [==============================] - 134s 5s/step - loss: 1.3370 - accuracy: 0.4771 - val_loss: 1.4403 - val_accuracy: 0.3950
# Epoch 50/50
# 30/30 [==============================] - 131s 4s/step - loss: 1.3333 - accuracy: 0.4792 - val_loss: 1.4311 - val_accuracy: 0.4267
# CONFUSION MATRIX
# GENERATE LEARNING CURVES
