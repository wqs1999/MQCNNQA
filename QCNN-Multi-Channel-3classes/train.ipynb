# %%
# import packages
import os
#os.environ['CUDA_VISIBLE_DEVICES'] = '2'

# %%
import tensorflow as tf
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import time
from tensorflow.keras.utils import plot_model
import numpy as np


if not os.path.exists('output'):
    os.makedirs('output')

# %%
# 获取默认的 GPU 设备
default_gpu = tf.test.gpu_device_name()
print(default_gpu)

print(tf.config.list_physical_devices('GPU'))
# Out:
# /device:GPU:0
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 2024-11-15 12:33:13.571740: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-15 12:33:13.828266: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /device:GPU:0 with 640 MB memory:  -> device: 0, name: NVIDIA TITAN RTX, pci bus id: 0000:86:00.0, compute capability: 7.5

# %%
print("~~~~~~~~~~~MENU~~~~~~~~~~~~~")
print("1: COLORS")
print("2: COLORS_SHAPE")
print("3: 12-CHANNELS")
print("4: CIFAR-10")
print("Note: Run create_noisy_colors.py if first time running software")
datamenu1 = 4

datamenu2 = 0.001

datamenu3 = 3
    
print("Select models to run sequentially (y/n): ")

model1 = input('CO-QCNN (U1): ')

model6 = input('CO-QCNN (U2): ')

print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
# choose dataset to train on

if datamenu1 == 1: 
    datatype = "COLORS"
if datamenu1 == 2: 
    datatype = "COLORS_SHAPE"
if datamenu1 == 3: 
    datatype = "CHANNELS"
if datamenu1 == 4: 
    datatype = "CIFAR10"
    

# choose hyperparameters
num_of_epochs = 50
global_learning_rate = datamenu2
global_batch_size = 128

#classes of CIFAR-10 dataset
classes = datamenu3

# choose image size
resize_x = 10 
resize_y = 10 

# import project functions
# Out:
# ~~~~~~~~~~~MENU~~~~~~~~~~~~~
# 1: COLORS
# 2: COLORS_SHAPE
# 3: 12-CHANNELS
# 4: CIFAR-10
# Note: Run create_noisy_colors.py if first time running software
# Select models to run sequentially (y/n):
# CO-QCNN (U1):  n
# CO-QCNN (U2):  y
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %%
from prepare_data import datasize, build_model_datasets
import generate_output
import models

# list containing train size, image size x, image size y, learning_rate, batch size, test size, dataset, number of epochs
details = [datasize(datatype,classes)[0],resize_x,resize_y,global_learning_rate,global_batch_size,datasize(datatype,classes)[1],datatype,num_of_epochs]

# set model to True to run
############################
if model1 == "y":
    CO_U1_QCNN = True 
else:
    CO_U1_QCNN = False 


if model6 == "y":
    CO_U2_QCNN = True 
else:
    CO_U2_QCNN = False 
    

        

#############################
models_to_train = []
#############################
if CO_U1_QCNN:
    models_to_train.append(models.CO_U1_QCNN_model(datatype,classes))
    

if CO_U2_QCNN:
    models_to_train.append(models.CO_U2_QCNN_model(datatype,classes))

     
#############################

def train_model(model_to_train,classes):
    model = model_to_train
##########################
# print the architecture of the model
    model.summary()
############################
# grab the time the training starts, output folder will be named with this time
    timestr_ = time.strftime("%Y%m%d-%H%M%S")
# compile model
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=global_learning_rate), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# preprocess the chosen dataset
    model_data = build_model_datasets(datatype,details,classes)
# begin to train the model
    model_history = model.fit(model_data[0], model_data[2], validation_data=(model_data[1],model_data[3]) , epochs=num_of_epochs, batch_size=global_batch_size)
# create timestampped folder to save output
    os.mkdir('output/'+timestr_)
# create confusion matrix
    print("CONFUSION MATRIX")
    classes = model_data[4]
    y_pred = model.predict(model_data[1])
    y_pred = np.argmax(y_pred, axis=-1)
    y_pred = y_pred.flatten()
    if datatype == "CHANNELS" or datatype == "CIFAR10":
        y_true = model_data[3].flatten()
    else:
        y_true = model_data[3].numpy().flatten()
    confusion_mtx = confusion_matrix(y_true, y_pred, normalize='true')
    plt.figure(figsize=(16, 16))
    plt.figure()
    plt.imshow(confusion_mtx, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title('Confusion matrix')
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    timestr = time.strftime("%Y%m%d-%H%M%S")
    plt.savefig('output/'+timestr_+'/'+timestr+'_confusion_matrix.png', bbox_inches='tight')

# create learning curves plot
    print("GENERATE LEARNING CURVES")
    generate_output.save_output_imgs(model,model_history,details,timestr_)
# Out:
# 2024-11-15 12:33:32.158145: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 640 MB memory:  -> device: 0, name: NVIDIA TITAN RTX, pci bus id: 0000:86:00.0, compute capability: 7.5
# Circuit Depth: 18

# %%
# train all chosen models
for x in models_to_train:
    train_model(x,classes)
# Out:
# Model: "CO_U2_QCNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 10, 10, 3)]       0
#
#  CO_U2_QCNN (U2_circuit)     (None, 9, 9, 5)           105
#
#  max_pooling2d (MaxPooling2D  (None, 4, 4, 5)          0
#  )
#
#  flatten (Flatten)           (None, 80)                0
#
#  dense (Dense)               (None, 32)                2592
#
#  dense_1 (Dense)             (None, 3)                 99
#
# =================================================================
# Total params: 2,796
# Trainable params: 2,796
# Non-trainable params: 0
# _________________________________________________________________
# Preparing classes:
# ['airplane', 'automobile', 'bird']
# Training Images Per Class: 640
# Testing Images Per Class: 100
# Filtering Training Images: 100%|███████████████████████████████████████| 15000/15000 [00:14<00:00, 1048.91it/s]
# Filtering Testing Images: 100%|██████████████████████████████████████████| 3000/3000 [00:00<00:00, 7419.49it/s]
# Train Shape: (1920, 32, 32, 3)
# Test Shape: (300, 32, 32, 3)
# Epoch 1/50
# 2024-11-15 12:34:03.486988: I tensorflow/stream_executor/cuda/cuda_dnn.cc:366] Loaded cuDNN version 8902
# 15/15 [==============================] - 97s 6s/step - loss: 1.0958 - accuracy: 0.3844 - val_loss: 1.0928 - val_accuracy: 0.4500
# Epoch 2/50
# 15/15 [==============================] - 75s 5s/step - loss: 1.0907 - accuracy: 0.4276 - val_loss: 1.0848 - val_accuracy: 0.4433
# Epoch 3/50
# 15/15 [==============================] - 76s 5s/step - loss: 1.0838 - accuracy: 0.4344 - val_loss: 1.0747 - val_accuracy: 0.4467
# Epoch 4/50
# 15/15 [==============================] - 83s 6s/step - loss: 1.0739 - accuracy: 0.4510 - val_loss: 1.0634 - val_accuracy: 0.4800
# Epoch 5/50
# 15/15 [==============================] - 79s 5s/step - loss: 1.0630 - accuracy: 0.4667 - val_loss: 1.0498 - val_accuracy: 0.4733
# Epoch 6/50
# 15/15 [==============================] - 77s 5s/step - loss: 1.0508 - accuracy: 0.4828 - val_loss: 1.0361 - val_accuracy: 0.5200
# Epoch 7/50
# 15/15 [==============================] - 79s 5s/step - loss: 1.0351 - accuracy: 0.5010 - val_loss: 1.0211 - val_accuracy: 0.5100
# Epoch 8/50
# 15/15 [==============================] - 79s 5s/step - loss: 1.0196 - accuracy: 0.5344 - val_loss: 1.0074 - val_accuracy: 0.5267
# Epoch 9/50
# 15/15 [==============================] - 77s 5s/step - loss: 1.0058 - accuracy: 0.5526 - val_loss: 0.9945 - val_accuracy: 0.5167
# Epoch 10/50
# 15/15 [==============================] - 79s 5s/step - loss: 0.9926 - accuracy: 0.5391 - val_loss: 0.9833 - val_accuracy: 0.5333
# Epoch 11/50
# 15/15 [==============================] - 79s 5s/step - loss: 0.9783 - accuracy: 0.5599 - val_loss: 0.9746 - val_accuracy: 0.5400
# Epoch 12/50
# 15/15 [==============================] - 82s 6s/step - loss: 0.9661 - accuracy: 0.5724 - val_loss: 0.9669 - val_accuracy: 0.5633
# Epoch 13/50
# 15/15 [==============================] - 76s 5s/step - loss: 0.9537 - accuracy: 0.5948 - val_loss: 0.9596 - val_accuracy: 0.5467
# Epoch 14/50
# 15/15 [==============================] - 83s 6s/step - loss: 0.9434 - accuracy: 0.5786 - val_loss: 0.9531 - val_accuracy: 0.5833
# Epoch 15/50
# 15/15 [==============================] - 80s 5s/step - loss: 0.9345 - accuracy: 0.6042 - val_loss: 0.9479 - val_accuracy: 0.5533
# Epoch 16/50
# 15/15 [==============================] - 76s 5s/step - loss: 0.9230 - accuracy: 0.6078 - val_loss: 0.9378 - val_accuracy: 0.5733
# Epoch 17/50
# 15/15 [==============================] - 76s 5s/step - loss: 0.9141 - accuracy: 0.6010 - val_loss: 0.9373 - val_accuracy: 0.5633
# Epoch 18/50
# 15/15 [==============================] - 77s 5s/step - loss: 0.9040 - accuracy: 0.6016 - val_loss: 0.9302 - val_accuracy: 0.5433
# Epoch 19/50
# 15/15 [==============================] - 81s 5s/step - loss: 0.8932 - accuracy: 0.6203 - val_loss: 0.9178 - val_accuracy: 0.5667
# Epoch 20/50
# 15/15 [==============================] - 77s 5s/step - loss: 0.8864 - accuracy: 0.6260 - val_loss: 0.9149 - val_accuracy: 0.5633
# Epoch 21/50
# 15/15 [==============================] - 82s 6s/step - loss: 0.8796 - accuracy: 0.6198 - val_loss: 0.9080 - val_accuracy: 0.5867
# Epoch 22/50
# 15/15 [==============================] - 73s 5s/step - loss: 0.8673 - accuracy: 0.6208 - val_loss: 0.9060 - val_accuracy: 0.5733
# Epoch 23/50
# 15/15 [==============================] - 76s 5s/step - loss: 0.8589 - accuracy: 0.6271 - val_loss: 0.8990 - val_accuracy: 0.5800
# Epoch 24/50
# 15/15 [==============================] - 76s 5s/step - loss: 0.8516 - accuracy: 0.6292 - val_loss: 0.8922 - val_accuracy: 0.5767
# Epoch 25/50
# 15/15 [==============================] - 80s 5s/step - loss: 0.8423 - accuracy: 0.6339 - val_loss: 0.8927 - val_accuracy: 0.5733
# Epoch 26/50
# 15/15 [==============================] - 76s 5s/step - loss: 0.8391 - accuracy: 0.6339 - val_loss: 0.8814 - val_accuracy: 0.5900
# Epoch 27/50
# 15/15 [==============================] - 81s 5s/step - loss: 0.8298 - accuracy: 0.6458 - val_loss: 0.8810 - val_accuracy: 0.5667
# Epoch 28/50
# 15/15 [==============================] - 78s 5s/step - loss: 0.8254 - accuracy: 0.6391 - val_loss: 0.8837 - val_accuracy: 0.5767
# Epoch 29/50
# 15/15 [==============================] - 84s 6s/step - loss: 0.8203 - accuracy: 0.6354 - val_loss: 0.8703 - val_accuracy: 0.5800
# Epoch 30/50
# 15/15 [==============================] - 82s 6s/step - loss: 0.8118 - accuracy: 0.6401 - val_loss: 0.8696 - val_accuracy: 0.5967
# Epoch 31/50
# 15/15 [==============================] - 84s 6s/step - loss: 0.8080 - accuracy: 0.6365 - val_loss: 0.8659 - val_accuracy: 0.5767
# Epoch 32/50
# 15/15 [==============================] - 79s 5s/step - loss: 0.8013 - accuracy: 0.6505 - val_loss: 0.8636 - val_accuracy: 0.5700
# Epoch 33/50
# 15/15 [==============================] - 81s 6s/step - loss: 0.7967 - accuracy: 0.6531 - val_loss: 0.8600 - val_accuracy: 0.6067
# Epoch 34/50
# 15/15 [==============================] - 75s 5s/step - loss: 0.7913 - accuracy: 0.6516 - val_loss: 0.8562 - val_accuracy: 0.5867
# Epoch 35/50
# 15/15 [==============================] - 76s 5s/step - loss: 0.7885 - accuracy: 0.6495 - val_loss: 0.8516 - val_accuracy: 0.5933
# Epoch 36/50
# 15/15 [==============================] - 83s 6s/step - loss: 0.7819 - accuracy: 0.6552 - val_loss: 0.8504 - val_accuracy: 0.5933
# Epoch 37/50
# 15/15 [==============================] - 79s 5s/step - loss: 0.7784 - accuracy: 0.6589 - val_loss: 0.8474 - val_accuracy: 0.5900
# Epoch 38/50
# 15/15 [==============================] - 88s 6s/step - loss: 0.7801 - accuracy: 0.6609 - val_loss: 0.8579 - val_accuracy: 0.5900
# Epoch 39/50
# 15/15 [==============================] - 84s 6s/step - loss: 0.7717 - accuracy: 0.6667 - val_loss: 0.8449 - val_accuracy: 0.5900
# Epoch 40/50
# 15/15 [==============================] - 80s 5s/step - loss: 0.7646 - accuracy: 0.6609 - val_loss: 0.8387 - val_accuracy: 0.6000
# Epoch 41/50
# 15/15 [==============================] - 83s 6s/step - loss: 0.7635 - accuracy: 0.6677 - val_loss: 0.8373 - val_accuracy: 0.6100
# Epoch 42/50
# 15/15 [==============================] - 86s 6s/step - loss: 0.7540 - accuracy: 0.6719 - val_loss: 0.8441 - val_accuracy: 0.6233
# Epoch 43/50
# 15/15 [==============================] - 77s 5s/step - loss: 0.7549 - accuracy: 0.6708 - val_loss: 0.8316 - val_accuracy: 0.6400
# Epoch 44/50
# 15/15 [==============================] - 75s 5s/step - loss: 0.7492 - accuracy: 0.6740 - val_loss: 0.8507 - val_accuracy: 0.6100
# Epoch 45/50
# 15/15 [==============================] - 81s 5s/step - loss: 0.7546 - accuracy: 0.6745 - val_loss: 0.8322 - val_accuracy: 0.6333
# Epoch 46/50
# 15/15 [==============================] - 84s 6s/step - loss: 0.7430 - accuracy: 0.6849 - val_loss: 0.8272 - val_accuracy: 0.6267
# Epoch 47/50
# 15/15 [==============================] - 80s 5s/step - loss: 0.7413 - accuracy: 0.6839 - val_loss: 0.8269 - val_accuracy: 0.6267
# Epoch 48/50
# 15/15 [==============================] - 80s 5s/step - loss: 0.7363 - accuracy: 0.6833 - val_loss: 0.8313 - val_accuracy: 0.6133
# Epoch 49/50
# 15/15 [==============================] - 82s 6s/step - loss: 0.7346 - accuracy: 0.6828 - val_loss: 0.8184 - val_accuracy: 0.6400
# Epoch 50/50
# 15/15 [==============================] - 81s 5s/step - loss: 0.7273 - accuracy: 0.6901 - val_loss: 0.8213 - val_accuracy: 0.6500
# CONFUSION MATRIX
# GENERATE LEARNING CURVES

# %%
# Out:
# Training Images Per Class: 500
