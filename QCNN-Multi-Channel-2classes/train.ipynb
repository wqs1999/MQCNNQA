# %%
# import packages
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '2'

# %%
import tensorflow as tf
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import time
from tensorflow.keras.utils import plot_model
import numpy as np


if not os.path.exists('output'):
    os.makedirs('output')

# %%
# 获取默认的 GPU 设备
default_gpu = tf.test.gpu_device_name()
print(default_gpu)

print(tf.config.list_physical_devices('GPU'))
# Out:
# /device:GPU:0
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 2024-11-15 14:20:16.329405: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-15 14:20:17.616648: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /device:GPU:0 with 22991 MB memory:  -> device: 0, name: NVIDIA TITAN RTX, pci bus id: 0000:86:00.0, compute capability: 7.5

# %%
print("~~~~~~~~~~~MENU~~~~~~~~~~~~~")
print("1: COLORS")
print("2: COLORS_SHAPE")
print("3: 12-CHANNELS")
print("4: CIFAR-10")
print("Note: Run create_noisy_colors.py if first time running software")
datamenu1 = 4

datamenu2 = 0.001

datamenu3 = 2
    
print("Select models to run sequentially (y/n): ")

model1 = input('CO-QCNN (U1): ')

model6 = input('CO-QCNN (U2): ')

print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
# choose dataset to train on

if datamenu1 == 1: 
    datatype = "COLORS"
if datamenu1 == 2: 
    datatype = "COLORS_SHAPE"
if datamenu1 == 3: 
    datatype = "CHANNELS"
if datamenu1 == 4: 
    datatype = "CIFAR10"
    

# choose hyperparameters
num_of_epochs = 50
global_learning_rate = datamenu2
global_batch_size = 128

#classes of CIFAR-10 dataset
classes = datamenu3

# choose image size
resize_x = 10 
resize_y = 10 

# import project functions
# Out:
# ~~~~~~~~~~~MENU~~~~~~~~~~~~~
# 1: COLORS
# 2: COLORS_SHAPE
# 3: 12-CHANNELS
# 4: CIFAR-10
# Note: Run create_noisy_colors.py if first time running software
# Select models to run sequentially (y/n):
# CO-QCNN (U1):  n
# CO-QCNN (U2):  y
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %%
from prepare_data import datasize, build_model_datasets
import generate_output
import models

# list containing train size, image size x, image size y, learning_rate, batch size, test size, dataset, number of epochs
details = [datasize(datatype,classes)[0],resize_x,resize_y,global_learning_rate,global_batch_size,datasize(datatype,classes)[1],datatype,num_of_epochs]

# set model to True to run
############################
if model1 == "y":
    CO_U1_QCNN = True 
else:
    CO_U1_QCNN = False 


if model6 == "y":
    CO_U2_QCNN = True 
else:
    CO_U2_QCNN = False 
    

        

#############################
models_to_train = []
#############################
if CO_U1_QCNN:
    models_to_train.append(models.CO_U1_QCNN_model(datatype,classes))
    

if CO_U2_QCNN:
    models_to_train.append(models.CO_U2_QCNN_model(datatype,classes))

     
#############################

def train_model(model_to_train,classes):
    model = model_to_train
##########################
# print the architecture of the model
    model.summary()
############################
# grab the time the training starts, output folder will be named with this time
    timestr_ = time.strftime("%Y%m%d-%H%M%S")
# compile model
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=global_learning_rate), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# preprocess the chosen dataset
    model_data = build_model_datasets(datatype,details,classes)
# begin to train the model
    model_history = model.fit(model_data[0], model_data[2], validation_data=(model_data[1],model_data[3]) , epochs=num_of_epochs, batch_size=global_batch_size)
# create timestampped folder to save output
    os.mkdir('output/'+timestr_)
# create confusion matrix
    print("CONFUSION MATRIX")
    classes = model_data[4]
    y_pred = model.predict(model_data[1])
    y_pred = np.argmax(y_pred, axis=-1)
    y_pred = y_pred.flatten()
    if datatype == "CHANNELS" or datatype == "CIFAR10":
        y_true = model_data[3].flatten()
    else:
        y_true = model_data[3].numpy().flatten()
    confusion_mtx = confusion_matrix(y_true, y_pred, normalize='true')
    plt.figure(figsize=(16, 16))
    plt.figure()
    plt.imshow(confusion_mtx, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title('Confusion matrix')
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    timestr = time.strftime("%Y%m%d-%H%M%S")
    plt.savefig('output/'+timestr_+'/'+timestr+'_confusion_matrix.png', bbox_inches='tight')

# create learning curves plot
    print("GENERATE LEARNING CURVES")
    generate_output.save_output_imgs(model,model_history,details,timestr_)
# Out:
# 2024-11-15 14:20:25.671280: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22991 MB memory:  -> device: 0, name: NVIDIA TITAN RTX, pci bus id: 0000:86:00.0, compute capability: 7.5
# Circuit Depth: 18

# %%
# train all chosen models
for x in models_to_train:
    train_model(x,classes)
# Out:
# Model: "CO_U2_QCNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 10, 10, 3)]       0
#
#  CO_U2_QCNN (U2_circuit)     (None, 9, 9, 5)           105
#
#  max_pooling2d (MaxPooling2D  (None, 4, 4, 5)          0
#  )
#
#  flatten (Flatten)           (None, 80)                0
#
#  dense (Dense)               (None, 32)                2592
#
#  dense_1 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 2,763
# Trainable params: 2,763
# Non-trainable params: 0
# _________________________________________________________________
# Preparing classes:
# ['airplane', 'automobile']
# Training Images Per Class: 640
# Testing Images Per Class: 100
# Filtering Training Images: 100%|███████████████████████████████████████| 10000/10000 [00:05<00:00, 1995.43it/s]
# Filtering Testing Images: 100%|█████████████████████████████████████████| 2000/2000 [00:00<00:00, 12812.86it/s]
# Train Shape: (1280, 32, 32, 3)
# Test Shape: (200, 32, 32, 3)
# Epoch 1/50
# 2024-11-15 14:20:45.855760: I tensorflow/stream_executor/cuda/cuda_dnn.cc:366] Loaded cuDNN version 8902
# 10/10 [==============================] - 66s 6s/step - loss: 0.6938 - accuracy: 0.5148 - val_loss: 0.6866 - val_accuracy: 0.5900
# Epoch 2/50
# 10/10 [==============================] - 42s 4s/step - loss: 0.6881 - accuracy: 0.5242 - val_loss: 0.6810 - val_accuracy: 0.6450
# Epoch 3/50
# 10/10 [==============================] - 44s 4s/step - loss: 0.6819 - accuracy: 0.6102 - val_loss: 0.6747 - val_accuracy: 0.7050
# Epoch 4/50
# 10/10 [==============================] - 44s 4s/step - loss: 0.6749 - accuracy: 0.6687 - val_loss: 0.6671 - val_accuracy: 0.6800
# Epoch 5/50
# 10/10 [==============================] - 42s 4s/step - loss: 0.6693 - accuracy: 0.6586 - val_loss: 0.6582 - val_accuracy: 0.6800
# Epoch 6/50
# 10/10 [==============================] - 43s 4s/step - loss: 0.6594 - accuracy: 0.6805 - val_loss: 0.6473 - val_accuracy: 0.7450
# Epoch 7/50
# 10/10 [==============================] - 44s 5s/step - loss: 0.6497 - accuracy: 0.7031 - val_loss: 0.6340 - val_accuracy: 0.7150
# Epoch 8/50
# 10/10 [==============================] - 46s 5s/step - loss: 0.6390 - accuracy: 0.6984 - val_loss: 0.6192 - val_accuracy: 0.7200
# Epoch 9/50
# 10/10 [==============================] - 45s 5s/step - loss: 0.6266 - accuracy: 0.7047 - val_loss: 0.6041 - val_accuracy: 0.7250
# Epoch 10/50
# 10/10 [==============================] - 46s 5s/step - loss: 0.6150 - accuracy: 0.7000 - val_loss: 0.5896 - val_accuracy: 0.7400
# Epoch 11/50
# 10/10 [==============================] - 45s 4s/step - loss: 0.6030 - accuracy: 0.7023 - val_loss: 0.5774 - val_accuracy: 0.7300
# Epoch 12/50
# 10/10 [==============================] - 44s 5s/step - loss: 0.5928 - accuracy: 0.7164 - val_loss: 0.5670 - val_accuracy: 0.7450
# Epoch 13/50
# 10/10 [==============================] - 44s 4s/step - loss: 0.5857 - accuracy: 0.7156 - val_loss: 0.5587 - val_accuracy: 0.7300
# Epoch 14/50
# 10/10 [==============================] - 41s 4s/step - loss: 0.5746 - accuracy: 0.7219 - val_loss: 0.5502 - val_accuracy: 0.7650
# Epoch 15/50
# 10/10 [==============================] - 44s 4s/step - loss: 0.5668 - accuracy: 0.7344 - val_loss: 0.5442 - val_accuracy: 0.7450
# Epoch 16/50
# 10/10 [==============================] - 44s 5s/step - loss: 0.5626 - accuracy: 0.7273 - val_loss: 0.5408 - val_accuracy: 0.7400
# Epoch 17/50
# 10/10 [==============================] - 44s 4s/step - loss: 0.5558 - accuracy: 0.7297 - val_loss: 0.5373 - val_accuracy: 0.7550
# Epoch 18/50
# 10/10 [==============================] - 44s 4s/step - loss: 0.5507 - accuracy: 0.7352 - val_loss: 0.5316 - val_accuracy: 0.7500
# Epoch 19/50
# 10/10 [==============================] - 40s 4s/step - loss: 0.5420 - accuracy: 0.7445 - val_loss: 0.5286 - val_accuracy: 0.7450
# Epoch 20/50
# 10/10 [==============================] - 42s 4s/step - loss: 0.5374 - accuracy: 0.7422 - val_loss: 0.5247 - val_accuracy: 0.7500
# Epoch 21/50
# 10/10 [==============================] - 41s 4s/step - loss: 0.5320 - accuracy: 0.7578 - val_loss: 0.5204 - val_accuracy: 0.7400
# Epoch 22/50
# 10/10 [==============================] - 48s 5s/step - loss: 0.5269 - accuracy: 0.7539 - val_loss: 0.5213 - val_accuracy: 0.7550
# Epoch 23/50
# 10/10 [==============================] - 43s 4s/step - loss: 0.5242 - accuracy: 0.7633 - val_loss: 0.5157 - val_accuracy: 0.7450
# Epoch 24/50
# 10/10 [==============================] - 49s 5s/step - loss: 0.5183 - accuracy: 0.7609 - val_loss: 0.5132 - val_accuracy: 0.7500
# Epoch 25/50
# 10/10 [==============================] - 45s 5s/step - loss: 0.5126 - accuracy: 0.7617 - val_loss: 0.5149 - val_accuracy: 0.7550
# Epoch 26/50
# 10/10 [==============================] - 45s 5s/step - loss: 0.5086 - accuracy: 0.7656 - val_loss: 0.5072 - val_accuracy: 0.7400
# Epoch 27/50
# 10/10 [==============================] - 46s 5s/step - loss: 0.5028 - accuracy: 0.7711 - val_loss: 0.5086 - val_accuracy: 0.7550
# Epoch 28/50
# 10/10 [==============================] - 47s 5s/step - loss: 0.4990 - accuracy: 0.7727 - val_loss: 0.5047 - val_accuracy: 0.7350
# Epoch 29/50
# 10/10 [==============================] - 43s 4s/step - loss: 0.4944 - accuracy: 0.7773 - val_loss: 0.5029 - val_accuracy: 0.7500
# Epoch 30/50
# 10/10 [==============================] - 47s 5s/step - loss: 0.4902 - accuracy: 0.7758 - val_loss: 0.5025 - val_accuracy: 0.7600
# Epoch 31/50
# 10/10 [==============================] - 47s 5s/step - loss: 0.4907 - accuracy: 0.7750 - val_loss: 0.4989 - val_accuracy: 0.7600
# Epoch 32/50
# 10/10 [==============================] - 49s 5s/step - loss: 0.4899 - accuracy: 0.7828 - val_loss: 0.5069 - val_accuracy: 0.7450
# Epoch 33/50
# 10/10 [==============================] - 49s 5s/step - loss: 0.4926 - accuracy: 0.7695 - val_loss: 0.5018 - val_accuracy: 0.7750
# Epoch 34/50
# 10/10 [==============================] - 48s 5s/step - loss: 0.4763 - accuracy: 0.7844 - val_loss: 0.4911 - val_accuracy: 0.7550
# Epoch 35/50
# 10/10 [==============================] - 46s 5s/step - loss: 0.4739 - accuracy: 0.7875 - val_loss: 0.4891 - val_accuracy: 0.7700
# Epoch 36/50
# 10/10 [==============================] - 59s 6s/step - loss: 0.4722 - accuracy: 0.7883 - val_loss: 0.4926 - val_accuracy: 0.7700
# Epoch 37/50
# 10/10 [==============================] - 51s 5s/step - loss: 0.4748 - accuracy: 0.7859 - val_loss: 0.4922 - val_accuracy: 0.7600
# Epoch 38/50
# 10/10 [==============================] - 49s 5s/step - loss: 0.4650 - accuracy: 0.7945 - val_loss: 0.4855 - val_accuracy: 0.7500
# Epoch 39/50
# 10/10 [==============================] - 45s 5s/step - loss: 0.4637 - accuracy: 0.7937 - val_loss: 0.4869 - val_accuracy: 0.7700
# Epoch 40/50
# 10/10 [==============================] - 45s 4s/step - loss: 0.4664 - accuracy: 0.7930 - val_loss: 0.4879 - val_accuracy: 0.7650
# Epoch 41/50
# 10/10 [==============================] - 48s 5s/step - loss: 0.4618 - accuracy: 0.7922 - val_loss: 0.4958 - val_accuracy: 0.7650
# Epoch 42/50
# 10/10 [==============================] - 45s 5s/step - loss: 0.4605 - accuracy: 0.7977 - val_loss: 0.4811 - val_accuracy: 0.7700
# Epoch 43/50
# 10/10 [==============================] - 45s 5s/step - loss: 0.4547 - accuracy: 0.7992 - val_loss: 0.4824 - val_accuracy: 0.7700
# Epoch 44/50
# 10/10 [==============================] - 46s 5s/step - loss: 0.4553 - accuracy: 0.7914 - val_loss: 0.4920 - val_accuracy: 0.7700
# Epoch 45/50
# 10/10 [==============================] - 45s 4s/step - loss: 0.4542 - accuracy: 0.8023 - val_loss: 0.4838 - val_accuracy: 0.7650
# Epoch 46/50
# 10/10 [==============================] - 43s 4s/step - loss: 0.4502 - accuracy: 0.7984 - val_loss: 0.4825 - val_accuracy: 0.7650
# Epoch 47/50
# 10/10 [==============================] - 46s 5s/step - loss: 0.4475 - accuracy: 0.8070 - val_loss: 0.4771 - val_accuracy: 0.7650
# Epoch 48/50
# 10/10 [==============================] - 46s 5s/step - loss: 0.4475 - accuracy: 0.8039 - val_loss: 0.4782 - val_accuracy: 0.7600
# Epoch 49/50
# 10/10 [==============================] - 45s 5s/step - loss: 0.4485 - accuracy: 0.8055 - val_loss: 0.4894 - val_accuracy: 0.7650
# Epoch 50/50
# 10/10 [==============================] - 46s 5s/step - loss: 0.4461 - accuracy: 0.8062 - val_loss: 0.4793 - val_accuracy: 0.7650
# CONFUSION MATRIX
# GENERATE LEARNING CURVES
