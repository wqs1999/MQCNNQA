# %%
# import packages
import os
#os.environ['CUDA_VISIBLE_DEVICES'] = '2'

# %%
import tensorflow as tf
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import time
from tensorflow.keras.utils import plot_model
import numpy as np


if not os.path.exists('output'):
    os.makedirs('output')

# %%
# 获取默认的 GPU 设备
default_gpu = tf.test.gpu_device_name()
print(default_gpu)

print(tf.config.list_physical_devices('GPU'))
# Out:
# /device:GPU:0
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:2', device_type='GPU')]
# 2024-11-15 02:02:43.860198: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-15 02:02:45.087133: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /device:GPU:0 with 33147 MB memory:  -> device: 0, name: NVIDIA A100-PCIE-40GB, pci bus id: 0000:18:00.0, compute capability: 8.0
# 2024-11-15 02:02:45.089166: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /device:GPU:1 with 26279 MB memory:  -> device: 1, name: NVIDIA A100-PCIE-40GB, pci bus id: 0000:5e:00.0, compute capability: 8.0
# 2024-11-15 02:02:45.089741: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /device:GPU:2 with 660 MB memory:  -> device: 2, name: NVIDIA TITAN RTX, pci bus id: 0000:86:00.0, compute capability: 7.5

# %%
print("~~~~~~~~~~~MENU~~~~~~~~~~~~~")
print("1: COLORS")
print("2: COLORS_SHAPE")
print("3: 12-CHANNELS")
print("4: CIFAR-10")
print("Note: Run create_noisy_colors.py if first time running software")
datamenu1 = 4

datamenu2 = 0.001

datamenu3 = 7
    
print("Select models to run sequentially (y/n): ")

model1 = input('CO-QCNN (U1): ')

model6 = input('CO-QCNN (U2): ')

print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
# choose dataset to train on

if datamenu1 == 1: 
    datatype = "COLORS"
if datamenu1 == 2: 
    datatype = "COLORS_SHAPE"
if datamenu1 == 3: 
    datatype = "CHANNELS"
if datamenu1 == 4: 
    datatype = "CIFAR10"
    

# choose hyperparameters
num_of_epochs = 50
global_learning_rate = datamenu2
global_batch_size = 128

#classes of CIFAR-10 dataset
classes = datamenu3

# choose image size
resize_x = 10 
resize_y = 10 

# import project functions
# Out:
# ~~~~~~~~~~~MENU~~~~~~~~~~~~~
# 1: COLORS
# 2: COLORS_SHAPE
# 3: 12-CHANNELS
# 4: CIFAR-10
# Note: Run create_noisy_colors.py if first time running software
# Select models to run sequentially (y/n):
# CO-QCNN (U1):  n
# CO-QCNN (U2):  y
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %%
from prepare_data import datasize, build_model_datasets
import generate_output
import models

# list containing train size, image size x, image size y, learning_rate, batch size, test size, dataset, number of epochs
details = [datasize(datatype,classes)[0],resize_x,resize_y,global_learning_rate,global_batch_size,datasize(datatype,classes)[1],datatype,num_of_epochs]

# set model to True to run
############################
if model1 == "y":
    CO_U1_QCNN = True 
else:
    CO_U1_QCNN = False 


if model6 == "y":
    CO_U2_QCNN = True 
else:
    CO_U2_QCNN = False 
    

        

#############################
models_to_train = []
#############################
if CO_U1_QCNN:
    models_to_train.append(models.CO_U1_QCNN_model(datatype,classes))
    

if CO_U2_QCNN:
    models_to_train.append(models.CO_U2_QCNN_model(datatype,classes))

     
#############################

def train_model(model_to_train,classes):
    model = model_to_train
##########################
# print the architecture of the model
    model.summary()
############################
# grab the time the training starts, output folder will be named with this time
    timestr_ = time.strftime("%Y%m%d-%H%M%S")
# compile model
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=global_learning_rate), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# preprocess the chosen dataset
    model_data = build_model_datasets(datatype,details,classes)
# begin to train the model
    model_history = model.fit(model_data[0], model_data[2], validation_data=(model_data[1],model_data[3]) , epochs=num_of_epochs, batch_size=global_batch_size)
# create timestampped folder to save output
    os.mkdir('output/'+timestr_)
# create confusion matrix
    print("CONFUSION MATRIX")
    classes = model_data[4]
    y_pred = model.predict(model_data[1])
    y_pred = np.argmax(y_pred, axis=-1)
    y_pred = y_pred.flatten()
    if datatype == "CHANNELS" or datatype == "CIFAR10":
        y_true = model_data[3].flatten()
    else:
        y_true = model_data[3].numpy().flatten()
    confusion_mtx = confusion_matrix(y_true, y_pred, normalize='true')
    plt.figure(figsize=(16, 16))
    plt.figure()
    plt.imshow(confusion_mtx, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title('Confusion matrix')
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    timestr = time.strftime("%Y%m%d-%H%M%S")
    plt.savefig('output/'+timestr_+'/'+timestr+'_confusion_matrix.png', bbox_inches='tight')

# create learning curves plot
    print("GENERATE LEARNING CURVES")
    generate_output.save_output_imgs(model,model_history,details,timestr_)
# Out:
# 2024-11-15 02:03:01.918289: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 33147 MB memory:  -> device: 0, name: NVIDIA A100-PCIE-40GB, pci bus id: 0000:18:00.0, compute capability: 8.0
# 2024-11-15 02:03:01.919813: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 26279 MB memory:  -> device: 1, name: NVIDIA A100-PCIE-40GB, pci bus id: 0000:5e:00.0, compute capability: 8.0
# 2024-11-15 02:03:01.920004: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 660 MB memory:  -> device: 2, name: NVIDIA TITAN RTX, pci bus id: 0000:86:00.0, compute capability: 7.5
# Circuit Depth: 18

# %%
# train all chosen models
for x in models_to_train:
    train_model(x,classes)
# Out:
# Model: "CO_U2_QCNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 10, 10, 3)]       0
#
#  CO_U2_QCNN (U2_circuit)     (None, 9, 9, 5)           105
#
#  max_pooling2d (MaxPooling2D  (None, 4, 4, 5)          0
#  )
#
#  flatten (Flatten)           (None, 80)                0
#
#  dense (Dense)               (None, 32)                2592
#
#  dense_1 (Dense)             (None, 7)                 231
#
# =================================================================
# Total params: 2,928
# Trainable params: 2,928
# Non-trainable params: 0
# _________________________________________________________________
# Preparing classes:
# ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog']
# Training Images Per Class: 640
# Testing Images Per Class: 100
# Filtering Training Images: 100%|████████████████████████████████████████████████| 35000/35000 [01:10<00:00, 494.39it/s]
# Filtering Testing Images: 100%|██████████████████████████████████████████████████| 7000/7000 [00:02<00:00, 2964.84it/s]
# Train Shape: (4480, 32, 32, 3)
# Test Shape: (700, 32, 32, 3)
# Epoch 1/50
# 2024-11-15 02:04:32.432533: I tensorflow/stream_executor/cuda/cuda_dnn.cc:366] Loaded cuDNN version 8902
# 2024-11-15 02:04:32.476408: I tensorflow/stream_executor/cuda/cuda_blas.cc:1774] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 35/35 [==============================] - 217s 6s/step - loss: 1.9502 - accuracy: 0.1529 - val_loss: 1.9423 - val_accuracy: 0.1471
# Epoch 2/50
# 35/35 [==============================] - 214s 6s/step - loss: 1.9367 - accuracy: 0.1935 - val_loss: 1.9318 - val_accuracy: 0.2043
# Epoch 3/50
# 35/35 [==============================] - 186s 5s/step - loss: 1.9221 - accuracy: 0.2129 - val_loss: 1.9140 - val_accuracy: 0.2329
# Epoch 4/50
# 35/35 [==============================] - 185s 5s/step - loss: 1.8961 - accuracy: 0.2379 - val_loss: 1.8875 - val_accuracy: 0.2343
# Epoch 5/50
# 35/35 [==============================] - 185s 5s/step - loss: 1.8630 - accuracy: 0.2578 - val_loss: 1.8580 - val_accuracy: 0.2371
# Epoch 6/50
# 35/35 [==============================] - 179s 5s/step - loss: 1.8296 - accuracy: 0.2705 - val_loss: 1.8265 - val_accuracy: 0.2600
# Epoch 7/50
# 35/35 [==============================] - 191s 6s/step - loss: 1.7995 - accuracy: 0.2819 - val_loss: 1.7990 - val_accuracy: 0.2571
# Epoch 8/50
# 35/35 [==============================] - 182s 5s/step - loss: 1.7731 - accuracy: 0.2926 - val_loss: 1.7828 - val_accuracy: 0.2629
# Epoch 9/50
# 35/35 [==============================] - 192s 5s/step - loss: 1.7528 - accuracy: 0.2984 - val_loss: 1.7600 - val_accuracy: 0.2914
# Epoch 10/50
# 35/35 [==============================] - 177s 5s/step - loss: 1.7304 - accuracy: 0.3156 - val_loss: 1.7442 - val_accuracy: 0.3014
# Epoch 11/50
# 35/35 [==============================] - 178s 5s/step - loss: 1.7107 - accuracy: 0.3290 - val_loss: 1.7298 - val_accuracy: 0.3186
# Epoch 12/50
# 35/35 [==============================] - 182s 5s/step - loss: 1.6932 - accuracy: 0.3337 - val_loss: 1.7234 - val_accuracy: 0.3057
# Epoch 13/50
# 35/35 [==============================] - 187s 5s/step - loss: 1.6809 - accuracy: 0.3350 - val_loss: 1.7144 - val_accuracy: 0.3343
# Epoch 14/50
# 35/35 [==============================] - 179s 5s/step - loss: 1.6685 - accuracy: 0.3471 - val_loss: 1.6985 - val_accuracy: 0.3457
# Epoch 15/50
# 35/35 [==============================] - 186s 5s/step - loss: 1.6556 - accuracy: 0.3480 - val_loss: 1.6907 - val_accuracy: 0.3400
# Epoch 16/50
# 35/35 [==============================] - 188s 5s/step - loss: 1.6462 - accuracy: 0.3540 - val_loss: 1.6895 - val_accuracy: 0.3514
# Epoch 17/50
# 35/35 [==============================] - 182s 5s/step - loss: 1.6420 - accuracy: 0.3587 - val_loss: 1.6783 - val_accuracy: 0.3429
# Epoch 18/50
# 35/35 [==============================] - 185s 5s/step - loss: 1.6341 - accuracy: 0.3538 - val_loss: 1.6827 - val_accuracy: 0.3371
# Epoch 19/50
# 35/35 [==============================] - 190s 5s/step - loss: 1.6302 - accuracy: 0.3587 - val_loss: 1.6681 - val_accuracy: 0.3600
# Epoch 20/50
# 35/35 [==============================] - 189s 5s/step - loss: 1.6198 - accuracy: 0.3667 - val_loss: 1.6634 - val_accuracy: 0.3443
# Epoch 21/50
# 35/35 [==============================] - 177s 5s/step - loss: 1.6136 - accuracy: 0.3685 - val_loss: 1.6681 - val_accuracy: 0.3500
# Epoch 22/50
# 35/35 [==============================] - 184s 5s/step - loss: 1.6103 - accuracy: 0.3710 - val_loss: 1.6547 - val_accuracy: 0.3514
# Epoch 23/50
# 35/35 [==============================] - 178s 5s/step - loss: 1.6033 - accuracy: 0.3739 - val_loss: 1.6584 - val_accuracy: 0.3557
# Epoch 24/50
# 35/35 [==============================] - 184s 5s/step - loss: 1.5963 - accuracy: 0.3837 - val_loss: 1.6411 - val_accuracy: 0.3586
# Epoch 25/50
# 35/35 [==============================] - 182s 5s/step - loss: 1.5884 - accuracy: 0.3837 - val_loss: 1.6404 - val_accuracy: 0.3771
# Epoch 26/50
# 35/35 [==============================] - 184s 5s/step - loss: 1.5838 - accuracy: 0.3882 - val_loss: 1.6309 - val_accuracy: 0.3586
# Epoch 27/50
# 35/35 [==============================] - 184s 5s/step - loss: 1.5769 - accuracy: 0.3888 - val_loss: 1.6337 - val_accuracy: 0.3657
# Epoch 28/50
# 35/35 [==============================] - 180s 5s/step - loss: 1.5728 - accuracy: 0.3900 - val_loss: 1.6260 - val_accuracy: 0.3714
# Epoch 29/50
# 35/35 [==============================] - 176s 5s/step - loss: 1.5651 - accuracy: 0.3924 - val_loss: 1.6192 - val_accuracy: 0.3743
# Epoch 30/50
# 35/35 [==============================] - 196s 6s/step - loss: 1.5635 - accuracy: 0.3895 - val_loss: 1.6104 - val_accuracy: 0.3671
# Epoch 31/50
# 35/35 [==============================] - 186s 5s/step - loss: 1.5565 - accuracy: 0.3969 - val_loss: 1.6094 - val_accuracy: 0.3771
# Epoch 32/50
# 35/35 [==============================] - 187s 5s/step - loss: 1.5498 - accuracy: 0.3993 - val_loss: 1.6058 - val_accuracy: 0.3729
# Epoch 33/50
# 35/35 [==============================] - 185s 5s/step - loss: 1.5448 - accuracy: 0.4018 - val_loss: 1.5990 - val_accuracy: 0.3700
# Epoch 34/50
# 35/35 [==============================] - 188s 5s/step - loss: 1.5411 - accuracy: 0.4000 - val_loss: 1.5997 - val_accuracy: 0.3814
# Epoch 35/50
# 35/35 [==============================] - 184s 5s/step - loss: 1.5300 - accuracy: 0.4067 - val_loss: 1.5915 - val_accuracy: 0.3757
# Epoch 36/50
# 35/35 [==============================] - 190s 5s/step - loss: 1.5302 - accuracy: 0.4089 - val_loss: 1.5886 - val_accuracy: 0.3886
# Epoch 37/50
# 35/35 [==============================] - 184s 5s/step - loss: 1.5189 - accuracy: 0.4096 - val_loss: 1.5827 - val_accuracy: 0.3743
# Epoch 38/50
# 35/35 [==============================] - 184s 5s/step - loss: 1.5174 - accuracy: 0.4156 - val_loss: 1.5753 - val_accuracy: 0.3786
# Epoch 39/50
# 35/35 [==============================] - 186s 5s/step - loss: 1.5127 - accuracy: 0.4123 - val_loss: 1.5724 - val_accuracy: 0.3729
# Epoch 40/50
# 35/35 [==============================] - 197s 6s/step - loss: 1.5101 - accuracy: 0.4170 - val_loss: 1.5668 - val_accuracy: 0.3829
# Epoch 41/50
# 35/35 [==============================] - 179s 5s/step - loss: 1.4993 - accuracy: 0.4212 - val_loss: 1.5612 - val_accuracy: 0.3871
# Epoch 42/50
# 35/35 [==============================] - 188s 5s/step - loss: 1.4951 - accuracy: 0.4279 - val_loss: 1.5577 - val_accuracy: 0.3714
# Epoch 43/50
# 35/35 [==============================] - 183s 5s/step - loss: 1.4894 - accuracy: 0.4283 - val_loss: 1.5479 - val_accuracy: 0.3943
# Epoch 44/50
# 35/35 [==============================] - 186s 5s/step - loss: 1.4844 - accuracy: 0.4313 - val_loss: 1.5545 - val_accuracy: 0.3900
# Epoch 45/50
# 35/35 [==============================] - 175s 5s/step - loss: 1.4791 - accuracy: 0.4337 - val_loss: 1.5500 - val_accuracy: 0.4029
# Epoch 46/50
# 35/35 [==============================] - 178s 5s/step - loss: 1.4755 - accuracy: 0.4344 - val_loss: 1.5347 - val_accuracy: 0.3900
# Epoch 47/50
# 35/35 [==============================] - 187s 5s/step - loss: 1.4696 - accuracy: 0.4337 - val_loss: 1.5323 - val_accuracy: 0.4071
# Epoch 48/50
# 35/35 [==============================] - 191s 5s/step - loss: 1.4635 - accuracy: 0.4440 - val_loss: 1.5342 - val_accuracy: 0.3843
# Epoch 49/50
# 35/35 [==============================] - 185s 5s/step - loss: 1.4655 - accuracy: 0.4379 - val_loss: 1.5490 - val_accuracy: 0.3771
# Epoch 50/50
# 35/35 [==============================] - 186s 5s/step - loss: 1.4622 - accuracy: 0.4404 - val_loss: 1.5188 - val_accuracy: 0.3914
# CONFUSION MATRIX
# GENERATE LEARNING CURVES

# %%
# Out:
# Training Images Per Class: 500
