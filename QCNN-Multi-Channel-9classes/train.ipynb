# %%
# import packages
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '2'

# %%
import tensorflow as tf
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import time
from tensorflow.keras.utils import plot_model
import numpy as np


if not os.path.exists('output'):
    os.makedirs('output')

# %%
# 获取默认的 GPU 设备
default_gpu = tf.test.gpu_device_name()
print(default_gpu)

print(tf.config.list_physical_devices('GPU'))
# Out:
# /device:GPU:0
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 2024-11-14 20:37:10.683990: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-14 20:37:11.323758: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /device:GPU:0 with 640 MB memory:  -> device: 0, name: NVIDIA TITAN RTX, pci bus id: 0000:86:00.0, compute capability: 7.5

# %%
print("~~~~~~~~~~~MENU~~~~~~~~~~~~~")
print("1: COLORS")
print("2: COLORS_SHAPE")
print("3: 12-CHANNELS")
print("4: CIFAR-10")
print("Note: Run create_noisy_colors.py if first time running software")
datamenu1 = 4

datamenu2 = 0.001

datamenu3 = 9
    
print("Select models to run sequentially (y/n): ")

model1 = input('CO-QCNN (U1): ')

model6 = input('CO-QCNN (U2): ')

print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
# choose dataset to train on

if datamenu1 == 1: 
    datatype = "COLORS"
if datamenu1 == 2: 
    datatype = "COLORS_SHAPE"
if datamenu1 == 3: 
    datatype = "CHANNELS"
if datamenu1 == 4: 
    datatype = "CIFAR10"
    

# choose hyperparameters
num_of_epochs = 50
global_learning_rate = datamenu2
global_batch_size = 128

#classes of CIFAR-10 dataset
classes = datamenu3

# choose image size
resize_x = 10 
resize_y = 10 

# import project functions
# Out:
# ~~~~~~~~~~~MENU~~~~~~~~~~~~~
# 1: COLORS
# 2: COLORS_SHAPE
# 3: 12-CHANNELS
# 4: CIFAR-10
# Note: Run create_noisy_colors.py if first time running software
# Select models to run sequentially (y/n):
# CO-QCNN (U1):  n
# CO-QCNN (U2):  y
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %%
from prepare_data import datasize, build_model_datasets
import generate_output
import models

# list containing train size, image size x, image size y, learning_rate, batch size, test size, dataset, number of epochs
details = [datasize(datatype,classes)[0],resize_x,resize_y,global_learning_rate,global_batch_size,datasize(datatype,classes)[1],datatype,num_of_epochs]

# set model to True to run
############################
if model1 == "y":
    CO_U1_QCNN = True 
else:
    CO_U1_QCNN = False 


if model6 == "y":
    CO_U2_QCNN = True 
else:
    CO_U2_QCNN = False 
    

        

#############################
models_to_train = []
#############################
if CO_U1_QCNN:
    models_to_train.append(models.CO_U1_QCNN_model(datatype,classes))
    

if CO_U2_QCNN:
    models_to_train.append(models.CO_U2_QCNN_model(datatype,classes))

     
#############################

def train_model(model_to_train,classes):
    model = model_to_train
##########################
# print the architecture of the model
    model.summary()
############################
# grab the time the training starts, output folder will be named with this time
    timestr_ = time.strftime("%Y%m%d-%H%M%S")
# compile model
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=global_learning_rate), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# preprocess the chosen dataset
    model_data = build_model_datasets(datatype,details,classes)
# begin to train the model
    model_history = model.fit(model_data[0], model_data[2], validation_data=(model_data[1],model_data[3]) , epochs=num_of_epochs, batch_size=global_batch_size)
# create timestampped folder to save output
    os.mkdir('output/'+timestr_)
# create confusion matrix
    print("CONFUSION MATRIX")
    classes = model_data[4]
    y_pred = model.predict(model_data[1])
    y_pred = np.argmax(y_pred, axis=-1)
    y_pred = y_pred.flatten()
    if datatype == "CHANNELS" or datatype == "CIFAR10":
        y_true = model_data[3].flatten()
    else:
        y_true = model_data[3].numpy().flatten()
    confusion_mtx = confusion_matrix(y_true, y_pred, normalize='true')
    plt.figure(figsize=(16, 16))
    plt.figure()
    plt.imshow(confusion_mtx, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title('Confusion matrix')
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    timestr = time.strftime("%Y%m%d-%H%M%S")
    plt.savefig('output/'+timestr_+'/'+timestr+'_confusion_matrix.png', bbox_inches='tight')

# create learning curves plot
    print("GENERATE LEARNING CURVES")
    generate_output.save_output_imgs(model,model_history,details,timestr_)
# Out:
# 2024-11-14 20:37:22.412078: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 640 MB memory:  -> device: 0, name: NVIDIA TITAN RTX, pci bus id: 0000:86:00.0, compute capability: 7.5
# Circuit Depth: 18

# %%
# train all chosen models
for x in models_to_train:
    train_model(x,classes)
# Out:
# Model: "CO_U2_QCNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 10, 10, 3)]       0
#
#  CO_U2_QCNN (U2_circuit)     (None, 9, 9, 5)           105
#
#  max_pooling2d (MaxPooling2D  (None, 4, 4, 5)          0
#  )
#
#  flatten (Flatten)           (None, 80)                0
#
#  dense (Dense)               (None, 32)                2592
#
#  dense_1 (Dense)             (None, 9)                 297
#
# =================================================================
# Total params: 2,994
# Trainable params: 2,994
# Non-trainable params: 0
# _________________________________________________________________
# Preparing classes:
# ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship']
# Training Images Per Class: 640
# Testing Images Per Class: 100
# Filtering Training Images: 100%|█████████| 45000/45000 [01:57<00:00, 381.89it/s]
# Filtering Testing Images: 100%|███████████| 9000/9000 [00:03<00:00, 2492.62it/s]
# Train Shape: (5760, 32, 32, 3)
# Test Shape: (900, 32, 32, 3)
# Epoch 1/50
# 2024-11-14 20:39:41.282427: I tensorflow/stream_executor/cuda/cuda_dnn.cc:366] Loaded cuDNN version 8902
# 45/45 [==============================] - 278s 6s/step - loss: 2.1970 - accuracy: 0.1250 - val_loss: 2.1893 - val_accuracy: 0.1556
# Epoch 2/50
# 45/45 [==============================] - 229s 5s/step - loss: 2.1828 - accuracy: 0.1559 - val_loss: 2.1683 - val_accuracy: 0.1744
# Epoch 3/50
# 45/45 [==============================] - 222s 5s/step - loss: 2.1501 - accuracy: 0.1875 - val_loss: 2.1226 - val_accuracy: 0.1933
# Epoch 4/50
# 45/45 [==============================] - 213s 5s/step - loss: 2.0966 - accuracy: 0.2059 - val_loss: 2.0710 - val_accuracy: 0.2078
# Epoch 5/50
# 45/45 [==============================] - 217s 5s/step - loss: 2.0512 - accuracy: 0.2144 - val_loss: 2.0309 - val_accuracy: 0.2300
# Epoch 6/50
# 45/45 [==============================] - 232s 5s/step - loss: 2.0152 - accuracy: 0.2292 - val_loss: 2.0087 - val_accuracy: 0.2222
# Epoch 7/50
# 45/45 [==============================] - 211s 5s/step - loss: 1.9857 - accuracy: 0.2398 - val_loss: 1.9774 - val_accuracy: 0.2633
# Epoch 8/50
# 45/45 [==============================] - 214s 5s/step - loss: 1.9594 - accuracy: 0.2613 - val_loss: 1.9629 - val_accuracy: 0.2589
# Epoch 9/50
# 45/45 [==============================] - 222s 5s/step - loss: 1.9395 - accuracy: 0.2705 - val_loss: 1.9469 - val_accuracy: 0.2789
# Epoch 10/50
# 45/45 [==============================] - 221s 5s/step - loss: 1.9217 - accuracy: 0.2896 - val_loss: 1.9312 - val_accuracy: 0.2856
# Epoch 11/50
# 45/45 [==============================] - 224s 5s/step - loss: 1.9052 - accuracy: 0.2918 - val_loss: 1.9166 - val_accuracy: 0.2878
# Epoch 12/50
# 45/45 [==============================] - 210s 5s/step - loss: 1.8936 - accuracy: 0.2927 - val_loss: 1.9071 - val_accuracy: 0.3078
# Epoch 13/50
# 45/45 [==============================] - 212s 5s/step - loss: 1.8806 - accuracy: 0.2967 - val_loss: 1.8950 - val_accuracy: 0.3167
# Epoch 14/50
# 45/45 [==============================] - 204s 5s/step - loss: 1.8690 - accuracy: 0.3075 - val_loss: 1.8794 - val_accuracy: 0.3133
# Epoch 15/50
# 45/45 [==============================] - 198s 4s/step - loss: 1.8583 - accuracy: 0.3132 - val_loss: 1.8812 - val_accuracy: 0.3022
# Epoch 16/50
# 45/45 [==============================] - 205s 5s/step - loss: 1.8462 - accuracy: 0.3109 - val_loss: 1.8625 - val_accuracy: 0.3244
# Epoch 17/50
# 45/45 [==============================] - 196s 4s/step - loss: 1.8363 - accuracy: 0.3165 - val_loss: 1.8516 - val_accuracy: 0.3233
# Epoch 18/50
# 45/45 [==============================] - 206s 5s/step - loss: 1.8285 - accuracy: 0.3148 - val_loss: 1.8432 - val_accuracy: 0.3244
# Epoch 19/50
# 45/45 [==============================] - 213s 5s/step - loss: 1.8194 - accuracy: 0.3196 - val_loss: 1.8356 - val_accuracy: 0.3356
# Epoch 20/50
# 45/45 [==============================] - 202s 5s/step - loss: 1.8091 - accuracy: 0.3252 - val_loss: 1.8324 - val_accuracy: 0.3322
# Epoch 21/50
# 45/45 [==============================] - 202s 4s/step - loss: 1.8014 - accuracy: 0.3321 - val_loss: 1.8218 - val_accuracy: 0.3189
# Epoch 22/50
# 45/45 [==============================] - 203s 5s/step - loss: 1.7972 - accuracy: 0.3307 - val_loss: 1.8166 - val_accuracy: 0.3222
# Epoch 23/50
# 45/45 [==============================] - 213s 5s/step - loss: 1.7883 - accuracy: 0.3332 - val_loss: 1.8142 - val_accuracy: 0.3278
# Epoch 24/50
# 45/45 [==============================] - 214s 5s/step - loss: 1.7756 - accuracy: 0.3401 - val_loss: 1.8075 - val_accuracy: 0.3344
# Epoch 25/50
# 45/45 [==============================] - 200s 4s/step - loss: 1.7703 - accuracy: 0.3375 - val_loss: 1.7993 - val_accuracy: 0.3333
# Epoch 26/50
# 45/45 [==============================] - 204s 5s/step - loss: 1.7619 - accuracy: 0.3394 - val_loss: 1.7935 - val_accuracy: 0.3322
# Epoch 27/50
# 45/45 [==============================] - 219s 5s/step - loss: 1.7541 - accuracy: 0.3444 - val_loss: 1.7930 - val_accuracy: 0.3211
# Epoch 28/50
# 45/45 [==============================] - 213s 5s/step - loss: 1.7473 - accuracy: 0.3512 - val_loss: 1.7804 - val_accuracy: 0.3433
# Epoch 29/50
# 45/45 [==============================] - 221s 5s/step - loss: 1.7377 - accuracy: 0.3483 - val_loss: 1.7808 - val_accuracy: 0.3344
# Epoch 30/50
# 45/45 [==============================] - 213s 5s/step - loss: 1.7336 - accuracy: 0.3531 - val_loss: 1.7709 - val_accuracy: 0.3389
# Epoch 31/50
# 45/45 [==============================] - 212s 5s/step - loss: 1.7254 - accuracy: 0.3609 - val_loss: 1.7639 - val_accuracy: 0.3422
# Epoch 32/50
# 45/45 [==============================] - 208s 5s/step - loss: 1.7195 - accuracy: 0.3571 - val_loss: 1.7612 - val_accuracy: 0.3400
# Epoch 33/50
# 45/45 [==============================] - 208s 5s/step - loss: 1.7118 - accuracy: 0.3679 - val_loss: 1.7553 - val_accuracy: 0.3444
# Epoch 34/50
# 45/45 [==============================] - 212s 5s/step - loss: 1.7041 - accuracy: 0.3689 - val_loss: 1.7528 - val_accuracy: 0.3378
# Epoch 35/50
# 45/45 [==============================] - 217s 5s/step - loss: 1.6984 - accuracy: 0.3661 - val_loss: 1.7505 - val_accuracy: 0.3456
# Epoch 36/50
# 45/45 [==============================] - 227s 5s/step - loss: 1.6927 - accuracy: 0.3750 - val_loss: 1.7414 - val_accuracy: 0.3600
# Epoch 37/50
# 45/45 [==============================] - 218s 5s/step - loss: 1.6862 - accuracy: 0.3740 - val_loss: 1.7476 - val_accuracy: 0.3456
# Epoch 38/50
# 45/45 [==============================] - 213s 5s/step - loss: 1.6821 - accuracy: 0.3774 - val_loss: 1.7337 - val_accuracy: 0.3567
# Epoch 39/50
# 45/45 [==============================] - 215s 5s/step - loss: 1.6742 - accuracy: 0.3868 - val_loss: 1.7320 - val_accuracy: 0.3611
# Epoch 40/50
# 45/45 [==============================] - 209s 5s/step - loss: 1.6714 - accuracy: 0.3809 - val_loss: 1.7252 - val_accuracy: 0.3567
# Epoch 41/50
# 45/45 [==============================] - 200s 4s/step - loss: 1.6647 - accuracy: 0.3847 - val_loss: 1.7253 - val_accuracy: 0.3667
# Epoch 42/50
# 45/45 [==============================] - 199s 4s/step - loss: 1.6597 - accuracy: 0.3892 - val_loss: 1.7161 - val_accuracy: 0.3589
# Epoch 43/50
# 45/45 [==============================] - 199s 4s/step - loss: 1.6520 - accuracy: 0.3944 - val_loss: 1.7110 - val_accuracy: 0.3578
# Epoch 44/50
# 45/45 [==============================] - 203s 5s/step - loss: 1.6520 - accuracy: 0.3936 - val_loss: 1.7190 - val_accuracy: 0.3489
# Epoch 45/50
# 45/45 [==============================] - 209s 5s/step - loss: 1.6473 - accuracy: 0.3839 - val_loss: 1.7076 - val_accuracy: 0.3644
# Epoch 46/50
# 45/45 [==============================] - 205s 5s/step - loss: 1.6404 - accuracy: 0.3934 - val_loss: 1.7045 - val_accuracy: 0.3622
# Epoch 47/50
# 45/45 [==============================] - 201s 4s/step - loss: 1.6371 - accuracy: 0.3981 - val_loss: 1.7019 - val_accuracy: 0.3589
# Epoch 48/50
# 45/45 [==============================] - 208s 5s/step - loss: 1.6338 - accuracy: 0.3972 - val_loss: 1.7020 - val_accuracy: 0.3489
# Epoch 49/50
# 45/45 [==============================] - 207s 5s/step - loss: 1.6266 - accuracy: 0.4024 - val_loss: 1.6956 - val_accuracy: 0.3556
# Epoch 50/50
# 45/45 [==============================] - 205s 5s/step - loss: 1.6261 - accuracy: 0.4071 - val_loss: 1.6884 - val_accuracy: 0.3733
# CONFUSION MATRIX
# GENERATE LEARNING CURVES
