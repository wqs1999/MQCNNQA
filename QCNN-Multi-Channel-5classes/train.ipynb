# %%
# import packages
import os
#os.environ['CUDA_VISIBLE_DEVICES'] = '2'

# %%
import tensorflow as tf
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import time
from tensorflow.keras.utils import plot_model
import numpy as np


if not os.path.exists('output'):
    os.makedirs('output')

# %%
# 获取默认的 GPU 设备
default_gpu = tf.test.gpu_device_name()
print(default_gpu)

print(tf.config.list_physical_devices('GPU'))
# Out:
# /device:GPU:0
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:2', device_type='GPU')]
# 2024-11-14 23:45:01.857952: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /device:GPU:0 with 33147 MB memory:  -> device: 0, name: NVIDIA A100-PCIE-40GB, pci bus id: 0000:18:00.0, compute capability: 8.0
# 2024-11-14 23:45:01.859629: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /device:GPU:1 with 25496 MB memory:  -> device: 1, name: NVIDIA A100-PCIE-40GB, pci bus id: 0000:5e:00.0, compute capability: 8.0
# 2024-11-14 23:45:01.859925: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /device:GPU:2 with 660 MB memory:  -> device: 2, name: NVIDIA TITAN RTX, pci bus id: 0000:86:00.0, compute capability: 7.5

# %%
print("~~~~~~~~~~~MENU~~~~~~~~~~~~~")
print("1: COLORS")
print("2: COLORS_SHAPE")
print("3: 12-CHANNELS")
print("4: CIFAR-10")
print("Note: Run create_noisy_colors.py if first time running software")
datamenu1 = 4

datamenu2 = 0.001

datamenu3 = 5
    
print("Select models to run sequentially (y/n): ")

model1 = input('CO-QCNN (U1): ')

model6 = input('CO-QCNN (U2): ')

print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
# choose dataset to train on

if datamenu1 == 1: 
    datatype = "COLORS"
if datamenu1 == 2: 
    datatype = "COLORS_SHAPE"
if datamenu1 == 3: 
    datatype = "CHANNELS"
if datamenu1 == 4: 
    datatype = "CIFAR10"
    

# choose hyperparameters
num_of_epochs = 50
global_learning_rate = datamenu2
global_batch_size = 128

#classes of CIFAR-10 dataset
classes = datamenu3

# choose image size
resize_x = 10 
resize_y = 10 

# import project functions
# Out:
# ~~~~~~~~~~~MENU~~~~~~~~~~~~~
# 1: COLORS
# 2: COLORS_SHAPE
# 3: 12-CHANNELS
# 4: CIFAR-10
# Note: Run create_noisy_colors.py if first time running software
# Select models to run sequentially (y/n):
# CO-QCNN (U1):  n
# CO-QCNN (U2):  y
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %%
from prepare_data import datasize, build_model_datasets
import generate_output
import models

# list containing train size, image size x, image size y, learning_rate, batch size, test size, dataset, number of epochs
details = [datasize(datatype,classes)[0],resize_x,resize_y,global_learning_rate,global_batch_size,datasize(datatype,classes)[1],datatype,num_of_epochs]

# set model to True to run
############################
if model1 == "y":
    CO_U1_QCNN = True 
else:
    CO_U1_QCNN = False 


if model6 == "y":
    CO_U2_QCNN = True 
else:
    CO_U2_QCNN = False 
    

        

#############################
models_to_train = []
#############################
if CO_U1_QCNN:
    models_to_train.append(models.CO_U1_QCNN_model(datatype,classes))
    

if CO_U2_QCNN:
    models_to_train.append(models.CO_U2_QCNN_model(datatype,classes))

     
#############################

def train_model(model_to_train,classes):
    model = model_to_train
##########################
# print the architecture of the model
    model.summary()
############################
# grab the time the training starts, output folder will be named with this time
    timestr_ = time.strftime("%Y%m%d-%H%M%S")
# compile model
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=global_learning_rate), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# preprocess the chosen dataset
    model_data = build_model_datasets(datatype,details,classes)
# begin to train the model
    model_history = model.fit(model_data[0], model_data[2], validation_data=(model_data[1],model_data[3]) , epochs=num_of_epochs, batch_size=global_batch_size)
# create timestampped folder to save output
    os.mkdir('output/'+timestr_)
# create confusion matrix
    print("CONFUSION MATRIX")
    classes = model_data[4]
    y_pred = model.predict(model_data[1])
    y_pred = np.argmax(y_pred, axis=-1)
    y_pred = y_pred.flatten()
    if datatype == "CHANNELS" or datatype == "CIFAR10":
        y_true = model_data[3].flatten()
    else:
        y_true = model_data[3].numpy().flatten()
    confusion_mtx = confusion_matrix(y_true, y_pred, normalize='true')
    plt.figure(figsize=(16, 16))
    plt.figure()
    plt.imshow(confusion_mtx, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title('Confusion matrix')
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    timestr = time.strftime("%Y%m%d-%H%M%S")
    plt.savefig('output/'+timestr_+'/'+timestr+'_confusion_matrix.png', bbox_inches='tight')

# create learning curves plot
    print("GENERATE LEARNING CURVES")
    generate_output.save_output_imgs(model,model_history,details,timestr_)
# Out:
# 2024-11-14 23:45:21.794319: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 33147 MB memory:  -> device: 0, name: NVIDIA A100-PCIE-40GB, pci bus id: 0000:18:00.0, compute capability: 8.0
# 2024-11-14 23:45:21.796084: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 25496 MB memory:  -> device: 1, name: NVIDIA A100-PCIE-40GB, pci bus id: 0000:5e:00.0, compute capability: 8.0
# 2024-11-14 23:45:21.796477: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 660 MB memory:  -> device: 2, name: NVIDIA TITAN RTX, pci bus id: 0000:86:00.0, compute capability: 7.5
# Circuit Depth: 18

# %%
# train all chosen models
for x in models_to_train:
    train_model(x,classes)
# Out:
# Model: "CO_U2_QCNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 10, 10, 3)]       0
#
#  CO_U2_QCNN (U2_circuit)     (None, 9, 9, 5)           105
#
#  max_pooling2d (MaxPooling2D  (None, 4, 4, 5)          0
#  )
#
#  flatten (Flatten)           (None, 80)                0
#
#  dense (Dense)               (None, 32)                2592
#
#  dense_1 (Dense)             (None, 5)                 165
#
# =================================================================
# Total params: 2,862
# Trainable params: 2,862
# Non-trainable params: 0
# _________________________________________________________________
# Preparing classes:
# ['airplane', 'automobile', 'bird', 'cat', 'deer']
# Training Images Per Class: 640
# Testing Images Per Class: 100
# Filtering Training Images: 100%|█████████| 25000/25000 [00:43<00:00, 569.58it/s]
# 3200
# Filtering Testing Images: 100%|███████████| 5000/5000 [00:01<00:00, 3079.08it/s]
# 500
# Train Shape: (3200, 32, 32, 3)
# Test Shape: (500, 32, 32, 3)
# Epoch 1/50
# 2024-11-14 23:46:27.300988: I tensorflow/stream_executor/cuda/cuda_dnn.cc:366] Loaded cuDNN version 8902
# 2024-11-14 23:46:27.341990: I tensorflow/stream_executor/cuda/cuda_blas.cc:1774] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 25/25 [==============================] - 166s 6s/step - loss: 1.6033 - accuracy: 0.2400 - val_loss: 1.5969 - val_accuracy: 0.2700
# Epoch 2/50
# 25/25 [==============================] - 133s 5s/step - loss: 1.5919 - accuracy: 0.2972 - val_loss: 1.5827 - val_accuracy: 0.3340
# Epoch 3/50
# 25/25 [==============================] - 140s 6s/step - loss: 1.5771 - accuracy: 0.3047 - val_loss: 1.5648 - val_accuracy: 0.3300
# Epoch 4/50
# 25/25 [==============================] - 137s 5s/step - loss: 1.5553 - accuracy: 0.3275 - val_loss: 1.5444 - val_accuracy: 0.3440
# Epoch 5/50
# 25/25 [==============================] - 132s 5s/step - loss: 1.5314 - accuracy: 0.3406 - val_loss: 1.5196 - val_accuracy: 0.3340
# Epoch 6/50
# 25/25 [==============================] - 134s 5s/step - loss: 1.5085 - accuracy: 0.3478 - val_loss: 1.5001 - val_accuracy: 0.3700
# Epoch 7/50
# 25/25 [==============================] - 132s 5s/step - loss: 1.4898 - accuracy: 0.3688 - val_loss: 1.4845 - val_accuracy: 0.3680
# Epoch 8/50
# 25/25 [==============================] - 137s 5s/step - loss: 1.4717 - accuracy: 0.3872 - val_loss: 1.4666 - val_accuracy: 0.3600
# Epoch 9/50
# 25/25 [==============================] - 129s 5s/step - loss: 1.4561 - accuracy: 0.3884 - val_loss: 1.4575 - val_accuracy: 0.3860
# Epoch 10/50
# 25/25 [==============================] - 136s 5s/step - loss: 1.4445 - accuracy: 0.3916 - val_loss: 1.4586 - val_accuracy: 0.3640
# Epoch 11/50
# 25/25 [==============================] - 137s 6s/step - loss: 1.4331 - accuracy: 0.4022 - val_loss: 1.4409 - val_accuracy: 0.3720
# Epoch 12/50
# 25/25 [==============================] - 154s 6s/step - loss: 1.4183 - accuracy: 0.4187 - val_loss: 1.4306 - val_accuracy: 0.3840
# Epoch 13/50
# 25/25 [==============================] - 134s 5s/step - loss: 1.4060 - accuracy: 0.4200 - val_loss: 1.4228 - val_accuracy: 0.3780
# Epoch 14/50
# 25/25 [==============================] - 140s 6s/step - loss: 1.3972 - accuracy: 0.4263 - val_loss: 1.4159 - val_accuracy: 0.3780
# Epoch 15/50
# 25/25 [==============================] - 140s 6s/step - loss: 1.3840 - accuracy: 0.4406 - val_loss: 1.4094 - val_accuracy: 0.3880
# Epoch 16/50
# 25/25 [==============================] - 130s 5s/step - loss: 1.3747 - accuracy: 0.4387 - val_loss: 1.4017 - val_accuracy: 0.4000
# Epoch 17/50
# 25/25 [==============================] - 126s 5s/step - loss: 1.3655 - accuracy: 0.4516 - val_loss: 1.3976 - val_accuracy: 0.4300
# Epoch 18/50
# 25/25 [==============================] - 139s 6s/step - loss: 1.3556 - accuracy: 0.4491 - val_loss: 1.3941 - val_accuracy: 0.4200
# Epoch 19/50
# 25/25 [==============================] - 135s 5s/step - loss: 1.3471 - accuracy: 0.4575 - val_loss: 1.3800 - val_accuracy: 0.4180
# Epoch 20/50
# 25/25 [==============================] - 134s 5s/step - loss: 1.3372 - accuracy: 0.4591 - val_loss: 1.3771 - val_accuracy: 0.4200
# Epoch 21/50
# 25/25 [==============================] - 133s 5s/step - loss: 1.3359 - accuracy: 0.4625 - val_loss: 1.3726 - val_accuracy: 0.4360
# Epoch 22/50
# 25/25 [==============================] - 138s 6s/step - loss: 1.3230 - accuracy: 0.4756 - val_loss: 1.3602 - val_accuracy: 0.4200
# Epoch 23/50
# 25/25 [==============================] - 151s 6s/step - loss: 1.3168 - accuracy: 0.4672 - val_loss: 1.3571 - val_accuracy: 0.4200
# Epoch 24/50
# 25/25 [==============================] - 137s 6s/step - loss: 1.3118 - accuracy: 0.4669 - val_loss: 1.3594 - val_accuracy: 0.4240
# Epoch 25/50
# 25/25 [==============================] - 144s 6s/step - loss: 1.3069 - accuracy: 0.4762 - val_loss: 1.3501 - val_accuracy: 0.4380
# Epoch 26/50
# 25/25 [==============================] - 150s 6s/step - loss: 1.3025 - accuracy: 0.4725 - val_loss: 1.3472 - val_accuracy: 0.4340
# Epoch 27/50
# 25/25 [==============================] - 137s 5s/step - loss: 1.2935 - accuracy: 0.4803 - val_loss: 1.3376 - val_accuracy: 0.4520
# Epoch 28/50
# 25/25 [==============================] - 128s 5s/step - loss: 1.2885 - accuracy: 0.4772 - val_loss: 1.3376 - val_accuracy: 0.4420
# Epoch 29/50
# 25/25 [==============================] - 149s 6s/step - loss: 1.2814 - accuracy: 0.4816 - val_loss: 1.3336 - val_accuracy: 0.4360
# Epoch 30/50
# 25/25 [==============================] - 135s 5s/step - loss: 1.2803 - accuracy: 0.4797 - val_loss: 1.3267 - val_accuracy: 0.4640
# Epoch 31/50
# 25/25 [==============================] - 167s 7s/step - loss: 1.2714 - accuracy: 0.4875 - val_loss: 1.3211 - val_accuracy: 0.4360
# Epoch 32/50
# 25/25 [==============================] - 135s 5s/step - loss: 1.2666 - accuracy: 0.4922 - val_loss: 1.3173 - val_accuracy: 0.4580
# Epoch 33/50
# 25/25 [==============================] - 139s 6s/step - loss: 1.2600 - accuracy: 0.4869 - val_loss: 1.3139 - val_accuracy: 0.4620
# Epoch 34/50
# 25/25 [==============================] - 145s 6s/step - loss: 1.2587 - accuracy: 0.4897 - val_loss: 1.3160 - val_accuracy: 0.4480
# Epoch 35/50
# 25/25 [==============================] - 142s 6s/step - loss: 1.2531 - accuracy: 0.4891 - val_loss: 1.3107 - val_accuracy: 0.4420
# Epoch 36/50
# 25/25 [==============================] - 135s 5s/step - loss: 1.2496 - accuracy: 0.4925 - val_loss: 1.3038 - val_accuracy: 0.4440
# Epoch 37/50
# 25/25 [==============================] - 138s 5s/step - loss: 1.2404 - accuracy: 0.4947 - val_loss: 1.3054 - val_accuracy: 0.4520
# Epoch 38/50
# 25/25 [==============================] - 155s 6s/step - loss: 1.2435 - accuracy: 0.4931 - val_loss: 1.2966 - val_accuracy: 0.4400
# Epoch 39/50
# 25/25 [==============================] - 141s 6s/step - loss: 1.2324 - accuracy: 0.5009 - val_loss: 1.2927 - val_accuracy: 0.4560
# Epoch 40/50
# 25/25 [==============================] - 130s 5s/step - loss: 1.2277 - accuracy: 0.4972 - val_loss: 1.2887 - val_accuracy: 0.4640
# Epoch 41/50
# 25/25 [==============================] - 155s 6s/step - loss: 1.2241 - accuracy: 0.4997 - val_loss: 1.2877 - val_accuracy: 0.4540
# Epoch 42/50
# 25/25 [==============================] - 162s 7s/step - loss: 1.2162 - accuracy: 0.5103 - val_loss: 1.2810 - val_accuracy: 0.4740
# Epoch 43/50
# 25/25 [==============================] - 145s 6s/step - loss: 1.2150 - accuracy: 0.5019 - val_loss: 1.2892 - val_accuracy: 0.4540
# Epoch 44/50
# 25/25 [==============================] - 155s 6s/step - loss: 1.2104 - accuracy: 0.5078 - val_loss: 1.2768 - val_accuracy: 0.4540
# Epoch 45/50
# 25/25 [==============================] - 137s 5s/step - loss: 1.2077 - accuracy: 0.5025 - val_loss: 1.2787 - val_accuracy: 0.4480
# Epoch 46/50
# 25/25 [==============================] - 161s 6s/step - loss: 1.2075 - accuracy: 0.5100 - val_loss: 1.2741 - val_accuracy: 0.4740
# Epoch 47/50
# 25/25 [==============================] - 156s 6s/step - loss: 1.2027 - accuracy: 0.5047 - val_loss: 1.2656 - val_accuracy: 0.4500
# Epoch 48/50
# 25/25 [==============================] - 144s 6s/step - loss: 1.1939 - accuracy: 0.5094 - val_loss: 1.2629 - val_accuracy: 0.4580
# Epoch 49/50
# 25/25 [==============================] - 142s 6s/step - loss: 1.1927 - accuracy: 0.5156 - val_loss: 1.2609 - val_accuracy: 0.4640
# Epoch 50/50
# 25/25 [==============================] - 154s 6s/step - loss: 1.1874 - accuracy: 0.5172 - val_loss: 1.2523 - val_accuracy: 0.4740
# CONFUSION MATRIX
# GENERATE LEARNING CURVES
