# %%
# import packages
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '2'

# %%
import tensorflow as tf
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import time
from tensorflow.keras.utils import plot_model
import numpy as np


if not os.path.exists('output'):
    os.makedirs('output')

# %%
# 获取默认的 GPU 设备
default_gpu = tf.test.gpu_device_name()
print(default_gpu)

print(tf.config.list_physical_devices('GPU'))
# Out:
# /device:GPU:0
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 2024-11-15 02:01:39.476518: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-15 02:01:40.111229: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /device:GPU:0 with 22991 MB memory:  -> device: 0, name: NVIDIA TITAN RTX, pci bus id: 0000:86:00.0, compute capability: 7.5

# %%
print("~~~~~~~~~~~MENU~~~~~~~~~~~~~")
print("1: COLORS")
print("2: COLORS_SHAPE")
print("3: 12-CHANNELS")
print("4: CIFAR-10")
print("Note: Run create_noisy_colors.py if first time running software")
datamenu1 = 4

datamenu2 = 0.001

datamenu3 = 8
    
print("Select models to run sequentially (y/n): ")

model1 = input('CO-QCNN (U1): ')

model6 = input('CO-QCNN (U2): ')

print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
# choose dataset to train on

if datamenu1 == 1: 
    datatype = "COLORS"
if datamenu1 == 2: 
    datatype = "COLORS_SHAPE"
if datamenu1 == 3: 
    datatype = "CHANNELS"
if datamenu1 == 4: 
    datatype = "CIFAR10"
    

# choose hyperparameters
num_of_epochs = 50
global_learning_rate = datamenu2
global_batch_size = 128

#classes of CIFAR-10 dataset
classes = datamenu3

# choose image size
resize_x = 10 
resize_y = 10 

# import project functions
# Out:
# ~~~~~~~~~~~MENU~~~~~~~~~~~~~
# 1: COLORS
# 2: COLORS_SHAPE
# 3: 12-CHANNELS
# 4: CIFAR-10
# Note: Run create_noisy_colors.py if first time running software
# Select models to run sequentially (y/n):
# CO-QCNN (U1):  n
# CO-QCNN (U2):  y
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %%
from prepare_data import datasize, build_model_datasets
import generate_output
import models

# list containing train size, image size x, image size y, learning_rate, batch size, test size, dataset, number of epochs
details = [datasize(datatype,classes)[0],resize_x,resize_y,global_learning_rate,global_batch_size,datasize(datatype,classes)[1],datatype,num_of_epochs]

# set model to True to run
############################
if model1 == "y":
    CO_U1_QCNN = True 
else:
    CO_U1_QCNN = False 


if model6 == "y":
    CO_U2_QCNN = True 
else:
    CO_U2_QCNN = False 
    

        

#############################
models_to_train = []
#############################
if CO_U1_QCNN:
    models_to_train.append(models.CO_U1_QCNN_model(datatype,classes))
    

if CO_U2_QCNN:
    models_to_train.append(models.CO_U2_QCNN_model(datatype,classes))

     
#############################

def train_model(model_to_train,classes):
    model = model_to_train
##########################
# print the architecture of the model
    model.summary()
############################
# grab the time the training starts, output folder will be named with this time
    timestr_ = time.strftime("%Y%m%d-%H%M%S")
# compile model
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=global_learning_rate), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# preprocess the chosen dataset
    model_data = build_model_datasets(datatype,details,classes)
# begin to train the model
    model_history = model.fit(model_data[0], model_data[2], validation_data=(model_data[1],model_data[3]) , epochs=num_of_epochs, batch_size=global_batch_size)
# create timestampped folder to save output
    os.mkdir('output/'+timestr_)
# create confusion matrix
    print("CONFUSION MATRIX")
    classes = model_data[4]
    y_pred = model.predict(model_data[1])
    y_pred = np.argmax(y_pred, axis=-1)
    y_pred = y_pred.flatten()
    if datatype == "CHANNELS" or datatype == "CIFAR10":
        y_true = model_data[3].flatten()
    else:
        y_true = model_data[3].numpy().flatten()
    confusion_mtx = confusion_matrix(y_true, y_pred, normalize='true')
    plt.figure(figsize=(16, 16))
    plt.figure()
    plt.imshow(confusion_mtx, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title('Confusion matrix')
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    timestr = time.strftime("%Y%m%d-%H%M%S")
    plt.savefig('output/'+timestr_+'/'+timestr+'_confusion_matrix.png', bbox_inches='tight')

# create learning curves plot
    print("GENERATE LEARNING CURVES")
    generate_output.save_output_imgs(model,model_history,details,timestr_)
# Out:
# 2024-11-15 02:02:10.740239: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22991 MB memory:  -> device: 0, name: NVIDIA TITAN RTX, pci bus id: 0000:86:00.0, compute capability: 7.5
# Circuit Depth: 18

# %%
# train all chosen models
for x in models_to_train:
    train_model(x,classes)
# Out:
# Model: "CO_U2_QCNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 10, 10, 3)]       0
#
#  CO_U2_QCNN (U2_circuit)     (None, 9, 9, 5)           105
#
#  max_pooling2d (MaxPooling2D  (None, 4, 4, 5)          0
#  )
#
#  flatten (Flatten)           (None, 80)                0
#
#  dense (Dense)               (None, 32)                2592
#
#  dense_1 (Dense)             (None, 8)                 264
#
# =================================================================
# Total params: 2,961
# Trainable params: 2,961
# Non-trainable params: 0
# _________________________________________________________________
# Preparing classes:
# ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse']
# Training Images Per Class: 640
# Testing Images Per Class: 100
# Filtering Training Images: 100%|████████████████████████████████████████████████| 40000/40000 [01:31<00:00, 437.25it/s]
# Filtering Testing Images: 100%|██████████████████████████████████████████████████| 8000/8000 [00:03<00:00, 2575.57it/s]
# Train Shape: (5120, 32, 32, 3)
# Test Shape: (800, 32, 32, 3)
# Epoch 1/50
# 2024-11-15 02:04:04.238038: I tensorflow/stream_executor/cuda/cuda_dnn.cc:366] Loaded cuDNN version 8902
# 40/40 [==============================] - 238s 6s/step - loss: 2.0785 - accuracy: 0.1340 - val_loss: 2.0728 - val_accuracy: 0.1775
# Epoch 2/50
# 40/40 [==============================] - 222s 6s/step - loss: 2.0667 - accuracy: 0.1762 - val_loss: 2.0581 - val_accuracy: 0.2225
# Epoch 3/50
# 40/40 [==============================] - 217s 5s/step - loss: 2.0485 - accuracy: 0.2113 - val_loss: 2.0340 - val_accuracy: 0.2362
# Epoch 4/50
# 40/40 [==============================] - 204s 5s/step - loss: 2.0179 - accuracy: 0.2301 - val_loss: 1.9993 - val_accuracy: 0.2537
# Epoch 5/50
# 40/40 [==============================] - 203s 5s/step - loss: 1.9770 - accuracy: 0.2471 - val_loss: 1.9590 - val_accuracy: 0.2625
# Epoch 6/50
# 40/40 [==============================] - 212s 5s/step - loss: 1.9397 - accuracy: 0.2584 - val_loss: 1.9283 - val_accuracy: 0.2750
# Epoch 7/50
# 40/40 [==============================] - 202s 5s/step - loss: 1.9117 - accuracy: 0.2730 - val_loss: 1.9122 - val_accuracy: 0.2763
# Epoch 8/50
# 40/40 [==============================] - 205s 5s/step - loss: 1.8916 - accuracy: 0.2828 - val_loss: 1.8946 - val_accuracy: 0.2912
# Epoch 9/50
# 40/40 [==============================] - 204s 5s/step - loss: 1.8716 - accuracy: 0.2943 - val_loss: 1.8788 - val_accuracy: 0.2850
# Epoch 10/50
# 40/40 [==============================] - 211s 5s/step - loss: 1.8542 - accuracy: 0.3139 - val_loss: 1.8691 - val_accuracy: 0.3025
# Epoch 11/50
# 40/40 [==============================] - 216s 5s/step - loss: 1.8402 - accuracy: 0.3148 - val_loss: 1.8607 - val_accuracy: 0.3100
# Epoch 12/50
# 40/40 [==============================] - 207s 5s/step - loss: 1.8296 - accuracy: 0.3154 - val_loss: 1.8484 - val_accuracy: 0.3175
# Epoch 13/50
# 40/40 [==============================] - 211s 5s/step - loss: 1.8137 - accuracy: 0.3277 - val_loss: 1.8325 - val_accuracy: 0.3363
# Epoch 14/50
# 40/40 [==============================] - 215s 5s/step - loss: 1.8055 - accuracy: 0.3297 - val_loss: 1.8312 - val_accuracy: 0.3088
# Epoch 15/50
# 40/40 [==============================] - 214s 5s/step - loss: 1.7949 - accuracy: 0.3414 - val_loss: 1.8204 - val_accuracy: 0.3388
# Epoch 16/50
# 40/40 [==============================] - 215s 5s/step - loss: 1.7838 - accuracy: 0.3414 - val_loss: 1.8111 - val_accuracy: 0.3363
# Epoch 17/50
# 40/40 [==============================] - 211s 5s/step - loss: 1.7763 - accuracy: 0.3463 - val_loss: 1.8100 - val_accuracy: 0.3400
# Epoch 18/50
# 40/40 [==============================] - 212s 5s/step - loss: 1.7721 - accuracy: 0.3457 - val_loss: 1.8075 - val_accuracy: 0.3363
# Epoch 19/50
# 40/40 [==============================] - 218s 5s/step - loss: 1.7620 - accuracy: 0.3525 - val_loss: 1.7921 - val_accuracy: 0.3487
# Epoch 20/50
# 40/40 [==============================] - 220s 5s/step - loss: 1.7519 - accuracy: 0.3492 - val_loss: 1.7926 - val_accuracy: 0.3413
# Epoch 21/50
# 40/40 [==============================] - 212s 5s/step - loss: 1.7492 - accuracy: 0.3484 - val_loss: 1.8002 - val_accuracy: 0.3425
# Epoch 22/50
# 40/40 [==============================] - 214s 5s/step - loss: 1.7399 - accuracy: 0.3586 - val_loss: 1.7772 - val_accuracy: 0.3537
# Epoch 23/50
# 40/40 [==============================] - 219s 6s/step - loss: 1.7369 - accuracy: 0.3557 - val_loss: 1.7705 - val_accuracy: 0.3550
# Epoch 24/50
# 40/40 [==============================] - 219s 5s/step - loss: 1.7250 - accuracy: 0.3654 - val_loss: 1.7655 - val_accuracy: 0.3625
# Epoch 25/50
# 40/40 [==============================] - 218s 5s/step - loss: 1.7199 - accuracy: 0.3623 - val_loss: 1.7611 - val_accuracy: 0.3638
# Epoch 26/50
# 40/40 [==============================] - 209s 5s/step - loss: 1.7147 - accuracy: 0.3633 - val_loss: 1.7546 - val_accuracy: 0.3613
# Epoch 27/50
# 40/40 [==============================] - 218s 5s/step - loss: 1.7054 - accuracy: 0.3736 - val_loss: 1.7575 - val_accuracy: 0.3562
# Epoch 28/50
# 40/40 [==============================] - 205s 5s/step - loss: 1.7009 - accuracy: 0.3730 - val_loss: 1.7593 - val_accuracy: 0.3500
# Epoch 29/50
# 40/40 [==============================] - 212s 5s/step - loss: 1.6956 - accuracy: 0.3734 - val_loss: 1.7430 - val_accuracy: 0.3550
# Epoch 30/50
# 40/40 [==============================] - 207s 5s/step - loss: 1.6893 - accuracy: 0.3809 - val_loss: 1.7379 - val_accuracy: 0.3762
# Epoch 31/50
# 40/40 [==============================] - 209s 5s/step - loss: 1.6842 - accuracy: 0.3807 - val_loss: 1.7340 - val_accuracy: 0.3787
# Epoch 32/50
# 40/40 [==============================] - 209s 5s/step - loss: 1.6767 - accuracy: 0.3842 - val_loss: 1.7348 - val_accuracy: 0.3700
# Epoch 33/50
# 40/40 [==============================] - 220s 6s/step - loss: 1.6689 - accuracy: 0.3867 - val_loss: 1.7216 - val_accuracy: 0.3800
# Epoch 34/50
# 40/40 [==============================] - 211s 5s/step - loss: 1.6644 - accuracy: 0.3871 - val_loss: 1.7169 - val_accuracy: 0.3688
# Epoch 35/50
# 40/40 [==============================] - 214s 5s/step - loss: 1.6578 - accuracy: 0.3891 - val_loss: 1.7221 - val_accuracy: 0.3700
# Epoch 36/50
# 40/40 [==============================] - 221s 6s/step - loss: 1.6507 - accuracy: 0.3963 - val_loss: 1.7077 - val_accuracy: 0.3688
# Epoch 37/50
# 40/40 [==============================] - 208s 5s/step - loss: 1.6432 - accuracy: 0.3986 - val_loss: 1.7154 - val_accuracy: 0.3725
# Epoch 38/50
# 40/40 [==============================] - 212s 5s/step - loss: 1.6415 - accuracy: 0.3971 - val_loss: 1.7056 - val_accuracy: 0.3812
# Epoch 39/50
# 40/40 [==============================] - 215s 5s/step - loss: 1.6328 - accuracy: 0.4004 - val_loss: 1.6943 - val_accuracy: 0.3887
# Epoch 40/50
# 40/40 [==============================] - 215s 5s/step - loss: 1.6234 - accuracy: 0.4098 - val_loss: 1.6893 - val_accuracy: 0.3887
# Epoch 41/50
# 40/40 [==============================] - 218s 5s/step - loss: 1.6180 - accuracy: 0.4109 - val_loss: 1.6886 - val_accuracy: 0.3938
# Epoch 42/50
# 40/40 [==============================] - 202s 5s/step - loss: 1.6144 - accuracy: 0.4072 - val_loss: 1.6821 - val_accuracy: 0.3963
# Epoch 43/50
# 40/40 [==============================] - 212s 5s/step - loss: 1.6093 - accuracy: 0.4113 - val_loss: 1.6743 - val_accuracy: 0.4025
# Epoch 44/50
# 40/40 [==============================] - 204s 5s/step - loss: 1.5981 - accuracy: 0.4191 - val_loss: 1.6728 - val_accuracy: 0.4013
# Epoch 45/50
# 40/40 [==============================] - 184s 5s/step - loss: 1.5926 - accuracy: 0.4184 - val_loss: 1.6673 - val_accuracy: 0.3875
# Epoch 46/50
# 40/40 [==============================] - 187s 5s/step - loss: 1.5888 - accuracy: 0.4240 - val_loss: 1.6671 - val_accuracy: 0.3812
# Epoch 47/50
# 40/40 [==============================] - 180s 5s/step - loss: 1.5849 - accuracy: 0.4201 - val_loss: 1.6647 - val_accuracy: 0.3938
# Epoch 48/50
# 40/40 [==============================] - 185s 5s/step - loss: 1.5777 - accuracy: 0.4303 - val_loss: 1.6650 - val_accuracy: 0.3825
# Epoch 49/50
# 40/40 [==============================] - 183s 5s/step - loss: 1.5732 - accuracy: 0.4283 - val_loss: 1.6592 - val_accuracy: 0.3887
# Epoch 50/50
# 40/40 [==============================] - 180s 5s/step - loss: 1.5677 - accuracy: 0.4254 - val_loss: 1.6551 - val_accuracy: 0.3950
# CONFUSION MATRIX
# GENERATE LEARNING CURVES
